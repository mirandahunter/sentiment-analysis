# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
import re
# Data Preprocessing
path = "RottenTomatoes/DataSet/train.tsv"
df = pd.read_csv(path, sep="\t") 

# remove punctuation
df['Phrase'] = df['Phrase'].str.replace(r'[^\w\s]+', '')
# remove numbers
df['Phrase'] = df['Phrase'].str.replace(r'\d+', '')
# make it all lower case
df['Phrase'] = df['Phrase'].str.lower()
# remove non-asci characters
df.Phrase.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
#df['Phrase'] = df['Phrase'].str.split()

df['Tokenized_text'] = df['Phrase'].apply(word_tokenize) 

df['Sentiment']=df['Sentiment'].astype(int) #convert the star_rating column to int
df['NNLabels'] = df['Sentiment'].div(4)

df= df[df['Sentiment']!=2]

#df['label']=np.where(df['Sentiment']>=4,1,0) #1-Positve,0-Negative
# convert to NumPy Array
#train = df['Phrase'].to_numpy()
from sklearn.model_selection import train_test_split
from nltk.stem.porter import *
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer

X_train,X_test,Y_train, Y_test = train_test_split(df['Phrase'], df['Sentiment'], test_size=0.2, random_state=30)
print("Train: " ,X_train.shape,Y_train.shape,"Test: ",(X_test.shape,Y_test.shape))

X_train,X_valid,Y_train, Y_valid = train_test_split(X_train,Y_train, test_size=0.5, random_state=30)
print("Train: " ,X_train.shape,Y_train.shape,"Test: ",(X_valid.shape,Y_valid.shape))
tfidfvectorizer = TfidfVectorizer(analyzer='word',stop_words= 'english')
tf_x_train = tfidfvectorizer.fit_transform(X_train)
tf_x_valid = tfidfvectorizer.transform(X_valid)
# Out:
# [nltk_data] Downloading package punkt to /Users/wjones/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /var/folders/01/r024mm7x74qd70l_5q2qs0hm0000gn/T/ipykernel_7406/4079153698.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Phrase'] = df['Phrase'].str.replace(r'[^\w\s]+', '')
# /var/folders/01/r024mm7x74qd70l_5q2qs0hm0000gn/T/ipykernel_7406/4079153698.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Phrase'] = df['Phrase'].str.replace(r'\d+', '')
# Train:  (61182,) (61182,) Test:  ((15296,), (15296,))
# Train:  (30591,) (30591,) Test:  ((30591,), (30591,))

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn.preprocessing import StandardScaler
K = 55
scale = StandardScaler()
X_train_normalized = scale.fit_transform(tf_x_train.toarray())
X_valid_normalized = scale.fit_transform(tf_x_valid.toarray())

# %%
kmeans = MiniBatchKMeans(n_clusters=K, random_state=10, n_init=10)
nn_X_train = kmeans.fit_transform(tf_x_train.toarray().astype(float))
preds = kmeans.fit_transform(tf_x_valid.toarray().astype(float))

# %%
nn_X_train_normalized = scale.fit_transform(nn_X_train)
nn_X_valid_normalized = scale.fit_transform(preds)

# %%
print(nn_X_valid_normalized.shape)
print(nn_X_train_normalized.shape)
# Out:
# (30591, 55)
# (30591, 55)

# %%
#from sklearn.preprocessing import OneHotEncoder
#encoder = OneHotEncoder(sparse=False)

# %%
#nn_Y_train = encoder.fit_transform(Y_train.array.reshape(-1,1))
#nn_Y_valid = encoder.fit_transform(Y_valid.array.reshape(-1,1))

# %%
#nn_Y_valid

# %%
import torch
import torch.nn as nn

# %%
class MLP(nn.Module):
  '''
    Multilayer Perceptron.
  '''
  def __init__(self):
    super().__init__()
    self.layers = nn.Sequential(
      nn.Flatten(),
      nn.Linear(55, 64),
      nn.ReLU(),
      nn.Linear(64, 32),
      nn.ReLU(),
      nn.Linear(32, 16),
      nn.ReLU(),
      nn.Linear(16,5),
      nn.LogSoftmax(dim=1)
    )


  def forward(self, x):
    '''Forward pass'''
    return self.layers(x)

# %%
import torch
import torch.nn as nn
# Define the number of input features



Y_tensor = torch.tensor(Y_train.array).long()
X_tensor = torch.tensor(nn_X_train_normalized).float()
mlp = MLP()
#print(X_tensor.shape)
# make a dataset object
dataset = torch.utils.data.TensorDataset(X_tensor, Y_tensor)

# then use it to make a dataloader object
trainloader = torch.utils.data.DataLoader(dataset, batch_size=10, shuffle=True, num_workers=4)
# make a scoring function
loss_function = nn.NLLLoss()
optimizer = torch.optim.Adam(mlp.parameters(), lr=0.001)

num_epochs = 50

for epoch in range(0, num_epochs): # num_epochs at maximum

      # Print epoch
      print(f'Starting epoch {epoch+1}')

      # Set current loss value
      current_loss = 0.0
      
      for i, data in enumerate(trainloader, 0):

            # Get inputs
            inputs, targets = data
            
            # Prepare targets
            #targets = targets.type(torch.FloatTensor).reshape((targets.shape[0], 4))

            # Zero the gradients
            optimizer.zero_grad()

            # Perform forward pass
            outputs = mlp(inputs)
            #print(outputs.shape)
            #print(targets[4].value)
            # Compute loss
            loss = loss_function(outputs, targets)

            # Perform backward pass
            loss.backward()

            # Perform optimization
            optimizer.step()

            # Print statistics

            current_loss += loss.item()
            if i % 500 == 499:
                  print('Loss after mini-batch %5d: %.3f' %
                        (i + 1, current_loss / 500))
                  current_loss = 0.0



#plt.scatter(trainX[:,0], trainX[:, 1], c=pred_labels)
# Out:
# Starting epoch 1
# Loss after mini-batch   500: 1.267
# Loss after mini-batch  1000: 1.196
# Loss after mini-batch  1500: 1.170
# Loss after mini-batch  2000: 1.174
# Loss after mini-batch  2500: 1.170
# Loss after mini-batch  3000: 1.158
# Starting epoch 2
# Loss after mini-batch   500: 1.152
# Loss after mini-batch  1000: 1.170
# Loss after mini-batch  1500: 1.165
# Loss after mini-batch  2000: 1.166
# Loss after mini-batch  2500: 1.170
# Loss after mini-batch  3000: 1.150
# Starting epoch 3
# Loss after mini-batch   500: 1.156
# Loss after mini-batch  1000: 1.142
# Loss after mini-batch  1500: 1.158
# Loss after mini-batch  2000: 1.161
# Loss after mini-batch  2500: 1.153
# Loss after mini-batch  3000: 1.174
# Starting epoch 4
# Loss after mini-batch   500: 1.145
# Loss after mini-batch  1000: 1.152
# Loss after mini-batch  1500: 1.136
# Loss after mini-batch  2000: 1.169
# Loss after mini-batch  2500: 1.157
# Loss after mini-batch  3000: 1.153
# Starting epoch 5
# Loss after mini-batch   500: 1.160
# Loss after mini-batch  1000: 1.144
# Loss after mini-batch  1500: 1.150
# Loss after mini-batch  2000: 1.146
# Loss after mini-batch  2500: 1.141
# Loss after mini-batch  3000: 1.156
# Starting epoch 6
# Loss after mini-batch   500: 1.137
# Loss after mini-batch  1000: 1.140
# Loss after mini-batch  1500: 1.140
# Loss after mini-batch  2000: 1.149
# Loss after mini-batch  2500: 1.148
# Loss after mini-batch  3000: 1.150
# Starting epoch 7
# Loss after mini-batch   500: 1.141
# Loss after mini-batch  1000: 1.129
# Loss after mini-batch  1500: 1.122
# Loss after mini-batch  2000: 1.152
# Loss after mini-batch  2500: 1.135
# Loss after mini-batch  3000: 1.154
# Starting epoch 8
# Loss after mini-batch   500: 1.128
# Loss after mini-batch  1000: 1.138
# Loss after mini-batch  1500: 1.141
# Loss after mini-batch  2000: 1.147
# Loss after mini-batch  2500: 1.128
# Loss after mini-batch  3000: 1.139
# Starting epoch 9
# Loss after mini-batch   500: 1.132
# Loss after mini-batch  1000: 1.150
# Loss after mini-batch  1500: 1.126
# Loss after mini-batch  2000: 1.124
# Loss after mini-batch  2500: 1.123
# Loss after mini-batch  3000: 1.145
# Starting epoch 10
# Loss after mini-batch   500: 1.124
# Loss after mini-batch  1000: 1.141
# Loss after mini-batch  1500: 1.141
# Loss after mini-batch  2000: 1.119
# Loss after mini-batch  2500: 1.125
# Loss after mini-batch  3000: 1.132
# Starting epoch 11
# Loss after mini-batch   500: 1.121
# Loss after mini-batch  1000: 1.130
# Loss after mini-batch  1500: 1.117
# Loss after mini-batch  2000: 1.131
# Loss after mini-batch  2500: 1.127
# Loss after mini-batch  3000: 1.140
# Starting epoch 12
# Loss after mini-batch   500: 1.120
# Loss after mini-batch  1000: 1.124
# Loss after mini-batch  1500: 1.124
# Loss after mini-batch  2000: 1.128
# Loss after mini-batch  2500: 1.128
# Loss after mini-batch  3000: 1.126
# Starting epoch 13
# Loss after mini-batch   500: 1.135
# Loss after mini-batch  1000: 1.126
# Loss after mini-batch  1500: 1.114
# Loss after mini-batch  2000: 1.114
# Loss after mini-batch  2500: 1.136
# Loss after mini-batch  3000: 1.119
# Starting epoch 14
# Loss after mini-batch   500: 1.118
# Loss after mini-batch  1000: 1.120
# Loss after mini-batch  1500: 1.115
# Loss after mini-batch  2000: 1.128
# Loss after mini-batch  2500: 1.122
# Loss after mini-batch  3000: 1.115
# Starting epoch 15
# Loss after mini-batch   500: 1.116
# Loss after mini-batch  1000: 1.099
# Loss after mini-batch  1500: 1.118
# Loss after mini-batch  2000: 1.138
# Loss after mini-batch  2500: 1.124
# Loss after mini-batch  3000: 1.120
# Starting epoch 16
# Loss after mini-batch   500: 1.126
# Loss after mini-batch  1000: 1.120
# Loss after mini-batch  1500: 1.116
# Loss after mini-batch  2000: 1.111
# Loss after mini-batch  2500: 1.109
# Loss after mini-batch  3000: 1.117
# Starting epoch 17
# Loss after mini-batch   500: 1.122
# Loss after mini-batch  1000: 1.115
# Loss after mini-batch  1500: 1.122
# Loss after mini-batch  2000: 1.113
# Loss after mini-batch  2500: 1.109
# Loss after mini-batch  3000: 1.113
# Starting epoch 18
# Loss after mini-batch   500: 1.117
# Loss after mini-batch  1000: 1.104
# Loss after mini-batch  1500: 1.114
# Loss after mini-batch  2000: 1.127
# Loss after mini-batch  2500: 1.110
# Loss after mini-batch  3000: 1.108
# Starting epoch 19
# Loss after mini-batch   500: 1.107
# Loss after mini-batch  1000: 1.119
# Loss after mini-batch  1500: 1.121
# Loss after mini-batch  2000: 1.158
# Loss after mini-batch  2500: 1.096
# Loss after mini-batch  3000: 1.109
# Starting epoch 20
# Loss after mini-batch   500: 1.091
# Loss after mini-batch  1000: 1.104
# Loss after mini-batch  1500: 1.115
# Loss after mini-batch  2000: 1.124
# Loss after mini-batch  2500: 1.116
# Loss after mini-batch  3000: 1.114
# Starting epoch 21
# Loss after mini-batch   500: 1.097
# Loss after mini-batch  1000: 1.107
# Loss after mini-batch  1500: 1.094
# Loss after mini-batch  2000: 1.117
# Loss after mini-batch  2500: 1.119
# Loss after mini-batch  3000: 1.117
# Starting epoch 22
# Loss after mini-batch   500: 1.092
# Loss after mini-batch  1000: 1.124
# Loss after mini-batch  1500: 1.114
# Loss after mini-batch  2000: 1.117
# Loss after mini-batch  2500: 1.093
# Loss after mini-batch  3000: 1.105
# Starting epoch 23
# Loss after mini-batch   500: 1.095
# Loss after mini-batch  1000: 1.097
# Loss after mini-batch  1500: 1.105
# Loss after mini-batch  2000: 1.110
# Loss after mini-batch  2500: 1.108
# Loss after mini-batch  3000: 1.116
# Starting epoch 24
# Loss after mini-batch   500: 1.105
# Loss after mini-batch  1000: 1.108
# Loss after mini-batch  1500: 1.105
# Loss after mini-batch  2000: 1.093
# Loss after mini-batch  2500: 1.113
# Loss after mini-batch  3000: 1.105
# Starting epoch 25
# Loss after mini-batch   500: 1.115
# Loss after mini-batch  1000: 1.088
# Loss after mini-batch  1500: 1.110
# Loss after mini-batch  2000: 1.108
# Loss after mini-batch  2500: 1.093
# Loss after mini-batch  3000: 1.106
# Starting epoch 26
# Loss after mini-batch   500: 1.108
# Loss after mini-batch  1000: 1.086
# Loss after mini-batch  1500: 1.105
# Loss after mini-batch  2000: 1.092
# Loss after mini-batch  2500: 1.097
# Loss after mini-batch  3000: 1.120
# Starting epoch 27
# Loss after mini-batch   500: 1.095
# Loss after mini-batch  1000: 1.095
# Loss after mini-batch  1500: 1.117
# Loss after mini-batch  2000: 1.097
# Loss after mini-batch  2500: 1.115
# Loss after mini-batch  3000: 1.089
# Starting epoch 28
# Loss after mini-batch   500: 1.100
# Loss after mini-batch  1000: 1.102
# Loss after mini-batch  1500: 1.101
# Loss after mini-batch  2000: 1.094
# Loss after mini-batch  2500: 1.111
# Loss after mini-batch  3000: 1.097
# Starting epoch 29
# Loss after mini-batch   500: 1.081
# Loss after mini-batch  1000: 1.105
# Loss after mini-batch  1500: 1.098
# Loss after mini-batch  2000: 1.105
# Loss after mini-batch  2500: 1.103
# Loss after mini-batch  3000: 1.096
# Starting epoch 30
# Loss after mini-batch   500: 1.095
# Loss after mini-batch  1000: 1.094
# Loss after mini-batch  1500: 1.093
# Loss after mini-batch  2000: 1.102
# Loss after mini-batch  2500: 1.094
# Loss after mini-batch  3000: 1.105
# Starting epoch 31
# Loss after mini-batch   500: 1.091
# Loss after mini-batch  1000: 1.093
# Loss after mini-batch  1500: 1.111
# Loss after mini-batch  2000: 1.089
# Loss after mini-batch  2500: 1.101
# Loss after mini-batch  3000: 1.097
# Starting epoch 32
# Loss after mini-batch   500: 1.081
# Loss after mini-batch  1000: 1.111
# Loss after mini-batch  1500: 1.094
# Loss after mini-batch  2000: 1.097
# Loss after mini-batch  2500: 1.081
# Loss after mini-batch  3000: 1.106
# Starting epoch 33
# Loss after mini-batch   500: 1.096
# Loss after mini-batch  1000: 1.096
# Loss after mini-batch  1500: 1.093
# Loss after mini-batch  2000: 1.093
# Loss after mini-batch  2500: 1.081
# Loss after mini-batch  3000: 1.105
# Starting epoch 34
# Loss after mini-batch   500: 1.105
# Loss after mini-batch  1000: 1.089
# Loss after mini-batch  1500: 1.083
# Loss after mini-batch  2000: 1.099
# Loss after mini-batch  2500: 1.090
# Loss after mini-batch  3000: 1.085
# Starting epoch 35
# Loss after mini-batch   500: 1.088
# Loss after mini-batch  1000: 1.085
# Loss after mini-batch  1500: 1.086
# Loss after mini-batch  2000: 1.097
# Loss after mini-batch  2500: 1.101
# Loss after mini-batch  3000: 1.095
# Starting epoch 36
# Loss after mini-batch   500: 1.085
# Loss after mini-batch  1000: 1.086
# Loss after mini-batch  1500: 1.108
# Loss after mini-batch  2000: 1.090
# Loss after mini-batch  2500: 1.084
# Loss after mini-batch  3000: 1.095
# Starting epoch 37
# Loss after mini-batch   500: 1.089
# Loss after mini-batch  1000: 1.099
# Loss after mini-batch  1500: 1.082
# Loss after mini-batch  2000: 1.091
# Loss after mini-batch  2500: 1.092
# Loss after mini-batch  3000: 1.105
# Starting epoch 38
# Loss after mini-batch   500: 1.101
# Loss after mini-batch  1000: 1.080
# Loss after mini-batch  1500: 1.083
# Loss after mini-batch  2000: 1.094
# Loss after mini-batch  2500: 1.087
# Loss after mini-batch  3000: 1.088
# Starting epoch 39
# Loss after mini-batch   500: 1.090
# Loss after mini-batch  1000: 1.084
# Loss after mini-batch  1500: 1.090
# Loss after mini-batch  2000: 1.094
# Loss after mini-batch  2500: 1.084
# Loss after mini-batch  3000: 1.092
# Starting epoch 40
# Loss after mini-batch   500: 1.094
# Loss after mini-batch  1000: 1.076
# Loss after mini-batch  1500: 1.088
# Loss after mini-batch  2000: 1.086
# Loss after mini-batch  2500: 1.104
# Loss after mini-batch  3000: 1.086
# Starting epoch 41
# Loss after mini-batch   500: 1.079
# Loss after mini-batch  1000: 1.084
# Loss after mini-batch  1500: 1.085
# Loss after mini-batch  2000: 1.079
# Loss after mini-batch  2500: 1.098
# Loss after mini-batch  3000: 1.099
# Starting epoch 42
# Loss after mini-batch   500: 1.087
# Loss after mini-batch  1000: 1.082
# Loss after mini-batch  1500: 1.074
# Loss after mini-batch  2000: 1.098
# Loss after mini-batch  2500: 1.078
# Loss after mini-batch  3000: 1.096
# Starting epoch 43
# Loss after mini-batch   500: 1.091
# Loss after mini-batch  1000: 1.071
# Loss after mini-batch  1500: 1.077
# Loss after mini-batch  2000: 1.096
# Loss after mini-batch  2500: 1.094
# Loss after mini-batch  3000: 1.089
# Starting epoch 44
# Loss after mini-batch   500: 1.083
# Loss after mini-batch  1000: 1.076
# Loss after mini-batch  1500: 1.075
# Loss after mini-batch  2000: 1.085
# Loss after mini-batch  2500: 1.102
# Loss after mini-batch  3000: 1.096
# Starting epoch 45
# Loss after mini-batch   500: 1.072
# Loss after mini-batch  1000: 1.072
# Loss after mini-batch  1500: 1.094
# Loss after mini-batch  2000: 1.090
# Loss after mini-batch  2500: 1.084
# Loss after mini-batch  3000: 1.091
# Starting epoch 46
# Loss after mini-batch   500: 1.080
# Loss after mini-batch  1000: 1.080
# Loss after mini-batch  1500: 1.074
# Loss after mini-batch  2000: 1.099
# Loss after mini-batch  2500: 1.095
# Loss after mini-batch  3000: 1.078
# Starting epoch 47
# Loss after mini-batch   500: 1.085
# Loss after mini-batch  1000: 1.072
# Loss after mini-batch  1500: 1.076
# Loss after mini-batch  2000: 1.079
# Loss after mini-batch  2500: 1.091
# Loss after mini-batch  3000: 1.094
# Starting epoch 48
# Loss after mini-batch   500: 1.073
# Loss after mini-batch  1000: 1.079
# Loss after mini-batch  1500: 1.079
# Loss after mini-batch  2000: 1.114
# Loss after mini-batch  2500: 1.085
# Loss after mini-batch  3000: 1.094
# Starting epoch 49
# Loss after mini-batch   500: 1.077
# Loss after mini-batch  1000: 1.077
# Loss after mini-batch  1500: 1.083
# Loss after mini-batch  2000: 1.080
# Loss after mini-batch  2500: 1.082
# Loss after mini-batch  3000: 1.090
# Starting epoch 50
# Loss after mini-batch   500: 1.069
# Loss after mini-batch  1000: 1.078
# Loss after mini-batch  1500: 1.073
# Loss after mini-batch  2000: 1.072
# Loss after mini-batch  2500: 1.097
# Loss after mini-batch  3000: 1.101

# %%
X_valid_tensor = torch.tensor(nn_X_valid_normalized).float()
preds = mlp(X_tensor).detach().numpy()

# %%
preds
# Out:
# array([[  -3.7406251 ,   -0.16749978, -124.57078   ,   -2.045095  ,
#           -6.7979527 ],
#        [  -3.0730174 ,   -0.26824874, -103.289604  ,   -1.6845431 ,
#           -5.6630354 ],
#        [  -2.3391626 ,   -0.51748246,  -90.87758   ,   -1.2252581 ,
#           -4.2765393 ],
#        ...,
#        [  -3.0724888 ,   -0.2683256 , -103.277145  ,   -1.6844051 ,
#           -5.6605167 ],
#        [  -3.0729973 ,   -0.26828748, -103.28547   ,   -1.6844013 ,
#           -5.6623297 ],
#        [  -3.0729558 ,   -0.2683688 , -103.2768    ,   -1.6841044 ,
#           -5.6608524 ]], dtype=float32)

# %%
test_output_labels = np.argmax(preds,1)

# %%
from sklearn.metrics import classification_report
report=classification_report(Y_train.array, test_output_labels.astype(int),output_dict=True)
report
# Out:
# {'0': {'precision': 0.060240963855421686,
#   'recall': 0.001787629603146228,
#   'f1-score': 0.003472222222222222,
#   'support': 2797},
#  '1': {'precision': 0.3562447611064543,
#   'recall': 0.8990159109721328,
#   'f1-score': 0.5102839841302986,
#   'support': 10873},
#  '3': {'precision': 0.44860994102780116,
#   'recall': 0.08056585218246463,
#   'f1-score': 0.13659975630090426,
#   'support': 13219},
#  '4': {'precision': 0.14388489208633093,
#   'recall': 0.02701242571582928,
#   'f1-score': 0.04548555833522856,
#   'support': 3702},
#  'accuracy': 0.35778496943545485,
#  'macro avg': {'precision': 0.252245139519002,
#   'recall': 0.2520954546183932,
#   'f1-score': 0.17396038024716343,
#   'support': 30591},
#  'weighted avg': {'precision': 0.3433944606048901,
#   'recall': 0.35778496943545485,
#   'f1-score': 0.24622043347726333,
#   'support': 30591}}

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
reports = []

for i in range(10,50):
  scale = StandardScaler()
  X_train_normalized = scale.fit_transform(tf_x_train.toarray())
  X_valid_normalized = scale.fit_transform(tf_x_valid.toarray())

  kmeans = MiniBatchKMeans(n_clusters=i, random_state=10, n_init=10)
  nn_X_train = kmeans.fit_transform(tf_x_train.toarray().astype(float))
  preds = kmeans.fit_transform(tf_x_valid.toarray().astype(float))
  nn_X_train_normalized = scale.fit_transform(nn_X_train)
  nn_X_valid_normalized = scale.fit_transform(preds)
  print(nn_X_valid_normalized.shape)
  print(nn_X_train_normalized.shape)
  #from sklearn.preprocessing import OneHotEncoder
  #encoder = OneHotEncoder(sparse=False)
  #nn_Y_train = encoder.fit_transform(Y_train.array.reshape(-1,1))
  #nn_Y_valid = encoder.fit_transform(Y_valid.array.reshape(-1,1))
  #nn_Y_valid
  import torch
  import torch.nn as nn
  class MLP(nn.Module):
    '''
      Multilayer Perceptron.
    '''
    def __init__(self):
      super().__init__()
      self.layers = nn.Sequential(
        nn.Flatten(),
        nn.Linear(i, 64),
        nn.ReLU(),
        nn.Linear(64, 32),
        nn.ReLU(),
        nn.Linear(32, 16),
        nn.ReLU(),
        nn.Linear(16,5),
        nn.LogSoftmax(dim=1)
      )


    def forward(self, x):
      '''Forward pass'''
      return self.layers(x)

  import torch
  import torch.nn as nn
  # Define the number of input features



  Y_tensor = torch.tensor(Y_train.array).long()
  X_tensor = torch.tensor(nn_X_train_normalized).float()
  mlp = MLP()
  #print(X_tensor.shape)
  # make a dataset object
  dataset = torch.utils.data.TensorDataset(X_tensor, Y_tensor)

  # then use it to make a dataloader object
  trainloader = torch.utils.data.DataLoader(dataset, batch_size=10, shuffle=True, num_workers=4)
  # make a scoring function
  loss_function = nn.NLLLoss()
  optimizer = torch.optim.Adam(mlp.parameters(), lr=0.001)

  num_epochs = 50

  for epoch in range(0, num_epochs): # num_epochs at maximum

        # Print epoch
        print(f'Starting epoch {epoch+1}')

        # Set current loss value
        current_loss = 0.0
        
        for i, data in enumerate(trainloader, 0):

              # Get inputs
              inputs, targets = data
              
              # Prepare targets
              #targets = targets.type(torch.FloatTensor).reshape((targets.shape[0], 4))

              # Zero the gradients
              optimizer.zero_grad()

              # Perform forward pass
              outputs = mlp(inputs)
              #print(outputs.shape)
              #print(targets[4].value)
              # Compute loss
              loss = loss_function(outputs, targets)

              # Perform backward pass
              loss.backward()

              # Perform optimization
              optimizer.step()

              # Print statistics

              current_loss += loss.item()
              if i % 500 == 499:
                    print('Loss after mini-batch %5d: %.3f' %
                          (i + 1, current_loss / 500))
                    current_loss = 0.0



  #plt.scatter(trainX[:,0], trainX[:, 1], c=pred_labels)



  X_valid_tensor = torch.tensor(nn_X_valid_normalized).float()
  preds = mlp(X_tensor).detach().numpy()

  preds
  test_output_labels = np.argmax(preds,1)

  report=classification_report(Y_train.array, test_output_labels.astype(int),output_dict=True)
  reports.append(report)
  print(report)
# Out:
# (30591, 10)
# (30591, 10)
# Starting epoch 1
# Loss after mini-batch   500: 1.281
# Loss after mini-batch  1000: 1.201
# Loss after mini-batch  1500: 1.203
# Loss after mini-batch  2000: 1.183
# Loss after mini-batch  2500: 1.181
# Loss after mini-batch  3000: 1.176
# Starting epoch 2
# Loss after mini-batch   500: 1.190
# Loss after mini-batch  1000: 1.173
# Loss after mini-batch  1500: 1.182
# Loss after mini-batch  2000: 1.181
# Loss after mini-batch  2500: 1.186
# Loss after mini-batch  3000: 1.183
# Starting epoch 3
# Loss after mini-batch   500: 1.186
# Loss after mini-batch  1000: 1.179
# Loss after mini-batch  1500: 1.185
# Loss after mini-batch  2000: 1.163
# Loss after mini-batch  2500: 1.173
# Loss after mini-batch  3000: 1.155
# Starting epoch 4
# Loss after mini-batch   500: 1.172
# Loss after mini-batch  1000: 1.168
# Loss after mini-batch  1500: 1.172
# Loss after mini-batch  2000: 1.163
# Loss after mini-batch  2500: 1.179
# Loss after mini-batch  3000: 1.152
# Starting epoch 5
# Loss after mini-batch   500: 1.176
# Loss after mini-batch  1000: 1.158
# Loss after mini-batch  1500: 1.153
# Loss after mini-batch  2000: 1.173
# Loss after mini-batch  2500: 1.168
# Loss after mini-batch  3000: 1.163
# Starting epoch 6
# Loss after mini-batch   500: 1.162
# Loss after mini-batch  1000: 1.170
# Loss after mini-batch  1500: 1.162
# Loss after mini-batch  2000: 1.167
# Loss after mini-batch  2500: 1.167
# Loss after mini-batch  3000: 1.150
# Starting epoch 7
# Loss after mini-batch   500: 1.158
# Loss after mini-batch  1000: 1.168
# Loss after mini-batch  1500: 1.176
# Loss after mini-batch  2000: 1.154
# Loss after mini-batch  2500: 1.160
# Loss after mini-batch  3000: 1.150
# Starting epoch 8
# Loss after mini-batch   500: 1.168
# Loss after mini-batch  1000: 1.161
# Loss after mini-batch  1500: 1.156
# Loss after mini-batch  2000: 1.145
# Loss after mini-batch  2500: 1.172
# Loss after mini-batch  3000: 1.162
# Starting epoch 9
# Loss after mini-batch   500: 1.169
# Loss after mini-batch  1000: 1.152
# Loss after mini-batch  1500: 1.149
# Loss after mini-batch  2000: 1.161
# Loss after mini-batch  2500: 1.162
# Loss after mini-batch  3000: 1.163
# Starting epoch 10
# Loss after mini-batch   500: 1.157
# Loss after mini-batch  1000: 1.166
# Loss after mini-batch  1500: 1.150
# Loss after mini-batch  2000: 1.174
# Loss after mini-batch  2500: 1.155
# Loss after mini-batch  3000: 1.154
# Starting epoch 11
# Loss after mini-batch   500: 1.151
# Loss after mini-batch  1000: 1.166
# Loss after mini-batch  1500: 1.152
# Loss after mini-batch  2000: 1.155
# Loss after mini-batch  2500: 1.175
# Loss after mini-batch  3000: 1.151
# Starting epoch 12
# Loss after mini-batch   500: 1.161
# Loss after mini-batch  1000: 1.159
# Loss after mini-batch  1500: 1.157
# Loss after mini-batch  2000: 1.151
# Loss after mini-batch  2500: 1.154
# Loss after mini-batch  3000: 1.170
# Starting epoch 13
# Loss after mini-batch   500: 1.154
# Loss after mini-batch  1000: 1.151
# Loss after mini-batch  1500: 1.159
# Loss after mini-batch  2000: 1.166
# Loss after mini-batch  2500: 1.158
# Loss after mini-batch  3000: 1.155
# Starting epoch 14
# Loss after mini-batch   500: 1.159
# Loss after mini-batch  1000: 1.158
# Loss after mini-batch  1500: 1.140
# Loss after mini-batch  2000: 1.167
# Loss after mini-batch  2500: 1.159
# Loss after mini-batch  3000: 1.153
# Starting epoch 15
# Loss after mini-batch   500: 1.145
# Loss after mini-batch  1000: 1.156
# Loss after mini-batch  1500: 1.166
# Loss after mini-batch  2000: 1.155
# Loss after mini-batch  2500: 1.148
# Loss after mini-batch  3000: 1.159
# Starting epoch 16
# Loss after mini-batch   500: 1.165
# Loss after mini-batch  1000: 1.149
# Loss after mini-batch  1500: 1.149
# Loss after mini-batch  2000: 1.160
# Loss after mini-batch  2500: 1.156
# Loss after mini-batch  3000: 1.157
# Starting epoch 17
# Loss after mini-batch   500: 1.155
# Loss after mini-batch  1000: 1.160
# Loss after mini-batch  1500: 1.155
# Loss after mini-batch  2000: 1.156
# Loss after mini-batch  2500: 1.144
# Loss after mini-batch  3000: 1.155
# Starting epoch 18
# Loss after mini-batch   500: 1.145
# Loss after mini-batch  1000: 1.152
# Loss after mini-batch  1500: 1.141
# Loss after mini-batch  2000: 1.153
# Loss after mini-batch  2500: 1.167
# Loss after mini-batch  3000: 1.174
# Starting epoch 19
# Loss after mini-batch   500: 1.147
# Loss after mini-batch  1000: 1.161
# Loss after mini-batch  1500: 1.166
# Loss after mini-batch  2000: 1.139
# Loss after mini-batch  2500: 1.141
# Loss after mini-batch  3000: 1.169
# Starting epoch 20
# Loss after mini-batch   500: 1.155
# Loss after mini-batch  1000: 1.149
# Loss after mini-batch  1500: 1.150
# Loss after mini-batch  2000: 1.160
# Loss after mini-batch  2500: 1.152
# Loss after mini-batch  3000: 1.152
# Starting epoch 21
# Loss after mini-batch   500: 1.150
# Loss after mini-batch  1000: 1.150
# Loss after mini-batch  1500: 1.153
# Loss after mini-batch  2000: 1.149
# Loss after mini-batch  2500: 1.158
# Loss after mini-batch  3000: 1.157
# Starting epoch 22
# Loss after mini-batch   500: 1.152
# Loss after mini-batch  1000: 1.150
# Loss after mini-batch  1500: 1.151
# Loss after mini-batch  2000: 1.156
# Loss after mini-batch  2500: 1.148
# Loss after mini-batch  3000: 1.152
# Starting epoch 23
# Loss after mini-batch   500: 1.142
# Loss after mini-batch  1000: 1.139
# Loss after mini-batch  1500: 1.155
# Loss after mini-batch  2000: 1.164
# Loss after mini-batch  2500: 1.155
# Loss after mini-batch  3000: 1.157
# Starting epoch 24
# Loss after mini-batch   500: 1.156
# Loss after mini-batch  1000: 1.148
# Loss after mini-batch  1500: 1.143
# Loss after mini-batch  2000: 1.147
# Loss after mini-batch  2500: 1.162
# Loss after mini-batch  3000: 1.153
# Starting epoch 25
# Loss after mini-batch   500: 1.158
# Loss after mini-batch  1000: 1.148
# Loss after mini-batch  1500: 1.148
# Loss after mini-batch  2000: 1.150
# Loss after mini-batch  2500: 1.153
# Loss after mini-batch  3000: 1.145
# Starting epoch 26
# Loss after mini-batch   500: 1.142
# Loss after mini-batch  1000: 1.165
# Loss after mini-batch  1500: 1.152
# Loss after mini-batch  2000: 1.133
# Loss after mini-batch  2500: 1.149
# Loss after mini-batch  3000: 1.158
# Starting epoch 27
# Loss after mini-batch   500: 1.145
# Loss after mini-batch  1000: 1.152
# Loss after mini-batch  1500: 1.139
# Loss after mini-batch  2000: 1.148
# Loss after mini-batch  2500: 1.158
# Loss after mini-batch  3000: 1.153
# Starting epoch 28
# Loss after mini-batch   500: 1.148
# Loss after mini-batch  1000: 1.147
# Loss after mini-batch  1500: 1.147
# Loss after mini-batch  2000: 1.141
# Loss after mini-batch  2500: 1.156
# Loss after mini-batch  3000: 1.151
# Starting epoch 29
# Loss after mini-batch   500: 1.134
# Loss after mini-batch  1000: 1.158
# Loss after mini-batch  1500: 1.151
# Loss after mini-batch  2000: 1.149
# Loss after mini-batch  2500: 1.140
# Loss after mini-batch  3000: 1.154
# Starting epoch 30
# Loss after mini-batch   500: 1.160
# Loss after mini-batch  1000: 1.138
# Loss after mini-batch  1500: 1.145
# Loss after mini-batch  2000: 1.147
# Loss after mini-batch  2500: 1.147
# Loss after mini-batch  3000: 1.156
# Starting epoch 31
# Loss after mini-batch   500: 1.146
# Loss after mini-batch  1000: 1.143
# Loss after mini-batch  1500: 1.148
# Loss after mini-batch  2000: 1.154
# Loss after mini-batch  2500: 1.143
# Loss after mini-batch  3000: 1.148
# Starting epoch 32
# Loss after mini-batch   500: 1.135
# Loss after mini-batch  1000: 1.149
# Loss after mini-batch  1500: 1.159
# Loss after mini-batch  2000: 1.145
# Loss after mini-batch  2500: 1.145
# Loss after mini-batch  3000: 1.149
# Starting epoch 33
# Loss after mini-batch   500: 1.161
# Loss after mini-batch  1000: 1.140
# Loss after mini-batch  1500: 1.150
# Loss after mini-batch  2000: 1.136
# Loss after mini-batch  2500: 1.147
# Loss after mini-batch  3000: 1.144
# Starting epoch 34
# Loss after mini-batch   500: 1.149
# Loss after mini-batch  1000: 1.154
# Loss after mini-batch  1500: 1.133
# Loss after mini-batch  2000: 1.146
# Loss after mini-batch  2500: 1.159
# Loss after mini-batch  3000: 1.140
# Starting epoch 35
# Loss after mini-batch   500: 1.144
# Loss after mini-batch  1000: 1.145
# Loss after mini-batch  1500: 1.148
# Loss after mini-batch  2000: 1.158
# Loss after mini-batch  2500: 1.137
# Loss after mini-batch  3000: 1.143
# Starting epoch 36
# Loss after mini-batch   500: 1.145
# Loss after mini-batch  1000: 1.145
# Loss after mini-batch  1500: 1.146
# Loss after mini-batch  2000: 1.148
# Loss after mini-batch  2500: 1.149
# Loss after mini-batch  3000: 1.142
# Starting epoch 37
# Loss after mini-batch   500: 1.149
# Loss after mini-batch  1000: 1.135
# Loss after mini-batch  1500: 1.145
# Loss after mini-batch  2000: 1.152
# Loss after mini-batch  2500: 1.141
# Loss after mini-batch  3000: 1.152
# Starting epoch 38
# Loss after mini-batch   500: 1.135
# Loss after mini-batch  1000: 1.134
# Loss after mini-batch  1500: 1.151
# Loss after mini-batch  2000: 1.148
# Loss after mini-batch  2500: 1.144
# Loss after mini-batch  3000: 1.158
# Starting epoch 39
# Loss after mini-batch   500: 1.144
# Loss after mini-batch  1000: 1.135
# Loss after mini-batch  1500: 1.157
# Loss after mini-batch  2000: 1.153
# Loss after mini-batch  2500: 1.144
# Loss after mini-batch  3000: 1.144
# Starting epoch 40
# Loss after mini-batch   500: 1.156
# Loss after mini-batch  1000: 1.140
# Loss after mini-batch  1500: 1.131
# Loss after mini-batch  2000: 1.153
# Loss after mini-batch  2500: 1.153
# Loss after mini-batch  3000: 1.138
# Starting epoch 41
# Loss after mini-batch   500: 1.139
# Loss after mini-batch  1000: 1.139
# Loss after mini-batch  1500: 1.147
# Loss after mini-batch  2000: 1.150
# Loss after mini-batch  2500: 1.140
# Loss after mini-batch  3000: 1.161
# Starting epoch 42
# Loss after mini-batch   500: 1.158
# Loss after mini-batch  1000: 1.156
# Loss after mini-batch  1500: 1.155
# Loss after mini-batch  2000: 1.130
# Loss after mini-batch  2500: 1.138
# Loss after mini-batch  3000: 1.133
# Starting epoch 43
# Loss after mini-batch   500: 1.152
# Loss after mini-batch  1000: 1.147
# Loss after mini-batch  1500: 1.142
# Loss after mini-batch  2000: 1.137
# Loss after mini-batch  2500: 1.144
# Loss after mini-batch  3000: 1.143
# Starting epoch 44
# Loss after mini-batch   500: 1.147
# Loss after mini-batch  1000: 1.136
# Loss after mini-batch  1500: 1.133
# Loss after mini-batch  2000: 1.130
# Loss after mini-batch  2500: 1.152
# Loss after mini-batch  3000: 1.152
# Starting epoch 45
# Loss after mini-batch   500: 1.134
# Loss after mini-batch  1000: 1.146
# Loss after mini-batch  1500: 1.139
# Loss after mini-batch  2000: 1.142
# Loss after mini-batch  2500: 1.149
# Loss after mini-batch  3000: 1.146
# Starting epoch 46
# Loss after mini-batch   500: 1.141
# Loss after mini-batch  1000: 1.141
# Loss after mini-batch  1500: 1.156
# Loss after mini-batch  2000: 1.147
# Loss after mini-batch  2500: 1.137
# Loss after mini-batch  3000: 1.134
# Starting epoch 47
# Loss after mini-batch   500: 1.150
# Loss after mini-batch  1000: 1.131
# Loss after mini-batch  1500: 1.141
# Loss after mini-batch  2000: 1.149
# Loss after mini-batch  2500: 1.148
# Loss after mini-batch  3000: 1.135
# Starting epoch 48
# Loss after mini-batch   500: 1.159
# Loss after mini-batch  1000: 1.143
# Loss after mini-batch  1500: 1.130
# Loss after mini-batch  2000: 1.138
# Loss after mini-batch  2500: 1.137
# Loss after mini-batch  3000: 1.141
# Starting epoch 49
# Loss after mini-batch   500: 1.143
# Loss after mini-batch  1000: 1.145
# Loss after mini-batch  1500: 1.139
# Loss after mini-batch  2000: 1.149
# Loss after mini-batch  2500: 1.134
# Loss after mini-batch  3000: 1.137
# Starting epoch 50
# Loss after mini-batch   500: 1.140
# Loss after mini-batch  1000: 1.137
# Loss after mini-batch  1500: 1.152
# Loss after mini-batch  2000: 1.133
# Loss after mini-batch  2500: 1.145
# Loss after mini-batch  3000: 1.142
# (30591, 11)
# (30591, 11)
# Starting epoch 1
# Loss after mini-batch   500: 1.281
# Loss after mini-batch  1000: 1.200
# Loss after mini-batch  1500: 1.185
# Loss after mini-batch  2000: 1.214
# Loss after mini-batch  2500: 1.193
# Loss after mini-batch  3000: 1.202
# Starting epoch 2
# Loss after mini-batch   500: 1.195
# Loss after mini-batch  1000: 1.197
# Loss after mini-batch  1500: 1.192
# Loss after mini-batch  2000: 1.190
# Loss after mini-batch  2500: 1.193
# Loss after mini-batch  3000: 1.199
# Starting epoch 3
# Loss after mini-batch   500: 1.188
# Loss after mini-batch  1000: 1.198
# Loss after mini-batch  1500: 1.203
# Loss after mini-batch  2000: 1.183
# Loss after mini-batch  2500: 1.184
# Loss after mini-batch  3000: 1.198
# Starting epoch 4
# Loss after mini-batch   500: 1.198
# Loss after mini-batch  1000: 1.178
# Loss after mini-batch  1500: 1.200
# Loss after mini-batch  2000: 1.177
# Loss after mini-batch  2500: 1.195
# Loss after mini-batch  3000: 1.191
# Starting epoch 5
# Loss after mini-batch   500: 1.189
# Loss after mini-batch  1000: 1.186
# Loss after mini-batch  1500: 1.180
# Loss after mini-batch  2000: 1.193
# Loss after mini-batch  2500: 1.190
# Loss after mini-batch  3000: 1.179
# Starting epoch 6
# Loss after mini-batch   500: 1.184
# Loss after mini-batch  1000: 1.184
# Loss after mini-batch  1500: 1.171
# Loss after mini-batch  2000: 1.170
# Loss after mini-batch  2500: 1.187
# Loss after mini-batch  3000: 1.184
# Starting epoch 7
# Loss after mini-batch   500: 1.186
# Loss after mini-batch  1000: 1.172
# Loss after mini-batch  1500: 1.172
# Loss after mini-batch  2000: 1.188
# Loss after mini-batch  2500: 1.167
# Loss after mini-batch  3000: 1.173
# Starting epoch 8
# Loss after mini-batch   500: 1.175
# Loss after mini-batch  1000: 1.185
# Loss after mini-batch  1500: 1.172
# Loss after mini-batch  2000: 1.173
# Loss after mini-batch  2500: 1.175
# Loss after mini-batch  3000: 1.158
# Starting epoch 9
# Loss after mini-batch   500: 1.174
# Loss after mini-batch  1000: 1.170
# Loss after mini-batch  1500: 1.170
# Loss after mini-batch  2000: 1.182
# Loss after mini-batch  2500: 1.172
# Loss after mini-batch  3000: 1.158
# Starting epoch 10
# Loss after mini-batch   500: 1.176
# Loss after mini-batch  1000: 1.169
# Loss after mini-batch  1500: 1.161
# Loss after mini-batch  2000: 1.179
# Loss after mini-batch  2500: 1.166
# Loss after mini-batch  3000: 1.164
# Starting epoch 11
# Loss after mini-batch   500: 1.162
# Loss after mini-batch  1000: 1.162
# Loss after mini-batch  1500: 1.184
# Loss after mini-batch  2000: 1.165
# Loss after mini-batch  2500: 1.169
# Loss after mini-batch  3000: 1.167
# Starting epoch 12
# Loss after mini-batch   500: 1.176
# Loss after mini-batch  1000: 1.167
# Loss after mini-batch  1500: 1.167
# Loss after mini-batch  2000: 1.176
# Loss after mini-batch  2500: 1.153
# Loss after mini-batch  3000: 1.168
# Starting epoch 13
# Loss after mini-batch   500: 1.164
# Loss after mini-batch  1000: 1.154
# Loss after mini-batch  1500: 1.171
# Loss after mini-batch  2000: 1.165
# Loss after mini-batch  2500: 1.181
# Loss after mini-batch  3000: 1.167
# Starting epoch 14
# Loss after mini-batch   500: 1.173
# Loss after mini-batch  1000: 1.164
# Loss after mini-batch  1500: 1.158
# Loss after mini-batch  2000: 1.169
# Loss after mini-batch  2500: 1.163
# Loss after mini-batch  3000: 1.172
# Starting epoch 15
# Loss after mini-batch   500: 1.166
# Loss after mini-batch  1000: 1.156
# Loss after mini-batch  1500: 1.164
# Loss after mini-batch  2000: 1.159
# Loss after mini-batch  2500: 1.171
# Loss after mini-batch  3000: 1.173
# Starting epoch 16
# Loss after mini-batch   500: 1.167
# Loss after mini-batch  1000: 1.164
# Loss after mini-batch  1500: 1.182
# Loss after mini-batch  2000: 1.151
# Loss after mini-batch  2500: 1.155
# Loss after mini-batch  3000: 1.172
# Starting epoch 17
# Loss after mini-batch   500: 1.159
# Loss after mini-batch  1000: 1.157
# Loss after mini-batch  1500: 1.171
# Loss after mini-batch  2000: 1.162
# Loss after mini-batch  2500: 1.169
# Loss after mini-batch  3000: 1.176
# Starting epoch 18
# Loss after mini-batch   500: 1.171
# Loss after mini-batch  1000: 1.185
# Loss after mini-batch  1500: 1.160
# Loss after mini-batch  2000: 1.164
# Loss after mini-batch  2500: 1.147
# Loss after mini-batch  3000: 1.168
# Starting epoch 19
# Loss after mini-batch   500: 1.168
# Loss after mini-batch  1000: 1.163
# Loss after mini-batch  1500: 1.175
# Loss after mini-batch  2000: 1.160
# Loss after mini-batch  2500: 1.166
# Loss after mini-batch  3000: 1.153
# Starting epoch 20
# Loss after mini-batch   500: 1.162
# Loss after mini-batch  1000: 1.154
# Loss after mini-batch  1500: 1.172
# Loss after mini-batch  2000: 1.155
# Loss after mini-batch  2500: 1.178
# Loss after mini-batch  3000: 1.162
# Starting epoch 21
# Loss after mini-batch   500: 1.173
# Loss after mini-batch  1000: 1.175
# Loss after mini-batch  1500: 1.166
# Loss after mini-batch  2000: 1.140
# Loss after mini-batch  2500: 1.179
# Loss after mini-batch  3000: 1.152
# Starting epoch 22
# Loss after mini-batch   500: 1.154
# Loss after mini-batch  1000: 1.173
# Loss after mini-batch  1500: 1.166
# Loss after mini-batch  2000: 1.163
# Loss after mini-batch  2500: 1.166
# Loss after mini-batch  3000: 1.160
# Starting epoch 23
# Loss after mini-batch   500: 1.160
# Loss after mini-batch  1000: 1.148
# Loss after mini-batch  1500: 1.173
# Loss after mini-batch  2000: 1.166
# Loss after mini-batch  2500: 1.167
# Loss after mini-batch  3000: 1.166
# Starting epoch 24
# Loss after mini-batch   500: 1.161
# Loss after mini-batch  1000: 1.158
# Loss after mini-batch  1500: 1.154
# Loss after mini-batch  2000: 1.164
# Loss after mini-batch  2500: 1.167
# Loss after mini-batch  3000: 1.175
# Starting epoch 25
# Loss after mini-batch   500: 1.165
# Loss after mini-batch  1000: 1.171
# Loss after mini-batch  1500: 1.152
# Loss after mini-batch  2000: 1.165
# Loss after mini-batch  2500: 1.162
# Loss after mini-batch  3000: 1.159
# Starting epoch 26
# Loss after mini-batch   500: 1.166
# Loss after mini-batch  1000: 1.153
# Loss after mini-batch  1500: 1.166
# Loss after mini-batch  2000: 1.152
# Loss after mini-batch  2500: 1.169
# Loss after mini-batch  3000: 1.166
# Starting epoch 27
# Loss after mini-batch   500: 1.160
# Loss after mini-batch  1000: 1.160
# Loss after mini-batch  1500: 1.170
# Loss after mini-batch  2000: 1.162
# Loss after mini-batch  2500: 1.163
# Loss after mini-batch  3000: 1.161
# Starting epoch 28
# Loss after mini-batch   500: 1.160
# Loss after mini-batch  1000: 1.156
# Loss after mini-batch  1500: 1.159
# Loss after mini-batch  2000: 1.165
# Loss after mini-batch  2500: 1.170
# Loss after mini-batch  3000: 1.156
# Starting epoch 29
# Loss after mini-batch   500: 1.147
# Loss after mini-batch  1000: 1.171
# Loss after mini-batch  1500: 1.161
# Loss after mini-batch  2000: 1.154
# Loss after mini-batch  2500: 1.165
# Loss after mini-batch  3000: 1.174
# Starting epoch 30
# Loss after mini-batch   500: 1.162
# Loss after mini-batch  1000: 1.172
# Loss after mini-batch  1500: 1.157
# Loss after mini-batch  2000: 1.158
# Loss after mini-batch  2500: 1.151
# Loss after mini-batch  3000: 1.171
# Starting epoch 31
# Loss after mini-batch   500: 1.158
# Loss after mini-batch  1000: 1.153
# Loss after mini-batch  1500: 1.158
# Loss after mini-batch  2000: 1.171
# Loss after mini-batch  2500: 1.167
# Loss after mini-batch  3000: 1.161
# Starting epoch 32
# Loss after mini-batch   500: 1.153
# Loss after mini-batch  1000: 1.180
# Loss after mini-batch  1500: 1.157
# Loss after mini-batch  2000: 1.167
# Loss after mini-batch  2500: 1.152
# Loss after mini-batch  3000: 1.160
# Starting epoch 33
# Loss after mini-batch   500: 1.168
# Loss after mini-batch  1000: 1.149
# Loss after mini-batch  1500: 1.169
# Loss after mini-batch  2000: 1.158
# Loss after mini-batch  2500: 1.146
# Loss after mini-batch  3000: 1.172
# Starting epoch 34
# Loss after mini-batch   500: 1.156
# Loss after mini-batch  1000: 1.169
# Loss after mini-batch  1500: 1.153
# Loss after mini-batch  2000: 1.170
# Loss after mini-batch  2500: 1.159
# Loss after mini-batch  3000: 1.158
# Starting epoch 35
# Loss after mini-batch   500: 1.162
# Loss after mini-batch  1000: 1.156
# Loss after mini-batch  1500: 1.161
# Loss after mini-batch  2000: 1.164
# Loss after mini-batch  2500: 1.160
# Loss after mini-batch  3000: 1.159
# Starting epoch 36
# Loss after mini-batch   500: 1.161
# Loss after mini-batch  1000: 1.154
# Loss after mini-batch  1500: 1.160
# Loss after mini-batch  2000: 1.167
# Loss after mini-batch  2500: 1.150
# Loss after mini-batch  3000: 1.173
# Starting epoch 37
# Loss after mini-batch   500: 1.155
# Loss after mini-batch  1000: 1.152
# Loss after mini-batch  1500: 1.159
# Loss after mini-batch  2000: 1.155
# Loss after mini-batch  2500: 1.165
# Loss after mini-batch  3000: 1.171
# Starting epoch 38
# Loss after mini-batch   500: 1.152
# Loss after mini-batch  1000: 1.165
# Loss after mini-batch  1500: 1.162
# Loss after mini-batch  2000: 1.158
# Loss after mini-batch  2500: 1.166
# Loss after mini-batch  3000: 1.154
# Starting epoch 39
# Loss after mini-batch   500: 1.160
# Loss after mini-batch  1000: 1.167
# Loss after mini-batch  1500: 1.177
# Loss after mini-batch  2000: 1.157
# Loss after mini-batch  2500: 1.144
# Loss after mini-batch  3000: 1.146
# Starting epoch 40
# Loss after mini-batch   500: 1.156
# Loss after mini-batch  1000: 1.166
# Loss after mini-batch  1500: 1.143
# Loss after mini-batch  2000: 1.169
# Loss after mini-batch  2500: 1.166
# Loss after mini-batch  3000: 1.151
# Starting epoch 41
# Loss after mini-batch   500: 1.147
# Loss after mini-batch  1000: 1.166
# Loss after mini-batch  1500: 1.151
# Loss after mini-batch  2000: 1.162
# Loss after mini-batch  2500: 1.164
# Loss after mini-batch  3000: 1.165
# Starting epoch 42
# Loss after mini-batch   500: 1.163
# Loss after mini-batch  1000: 1.147
# Loss after mini-batch  1500: 1.164
# Loss after mini-batch  2000: 1.158
# Loss after mini-batch  2500: 1.150
# Loss after mini-batch  3000: 1.169
# Starting epoch 43
# Loss after mini-batch   500: 1.160
# Loss after mini-batch  1000: 1.155
# Loss after mini-batch  1500: 1.158
# Loss after mini-batch  2000: 1.151
# Loss after mini-batch  2500: 1.159
# Loss after mini-batch  3000: 1.167
# Starting epoch 44
# Loss after mini-batch   500: 1.159
# Loss after mini-batch  1000: 1.168
# Loss after mini-batch  1500: 1.150
# Loss after mini-batch  2000: 1.159
# Loss after mini-batch  2500: 1.165
# Loss after mini-batch  3000: 1.151
# Starting epoch 45
# Loss after mini-batch   500: 1.163
# Loss after mini-batch  1000: 1.167
# Loss after mini-batch  1500: 1.157
# Loss after mini-batch  2000: 1.162
# Loss after mini-batch  2500: 1.146
# Loss after mini-batch  3000: 1.151
# Starting epoch 46
# Loss after mini-batch   500: 1.163
# Loss after mini-batch  1000: 1.154
# Loss after mini-batch  1500: 1.171
# Loss after mini-batch  2000: 1.154
# Loss after mini-batch  2500: 1.157
# Loss after mini-batch  3000: 1.153
# Starting epoch 47
# Loss after mini-batch   500: 1.150
# Loss after mini-batch  1000: 1.162
# Loss after mini-batch  1500: 1.159
# Loss after mini-batch  2000: 1.148
# Loss after mini-batch  2500: 1.161
# Loss after mini-batch  3000: 1.169
# Starting epoch 48
# Loss after mini-batch   500: 1.149
# Loss after mini-batch  1000: 1.146
# Loss after mini-batch  1500: 1.168
# Loss after mini-batch  2000: 1.161
# Loss after mini-batch  2500: 1.151
# Loss after mini-batch  3000: 1.168
# Starting epoch 49
# Loss after mini-batch   500: 1.162
# Loss after mini-batch  1000: 1.157
# Loss after mini-batch  1500: 1.160
# Loss after mini-batch  2000: 1.160
# Loss after mini-batch  2500: 1.156
# Loss after mini-batch  3000: 1.157
# Starting epoch 50
# Loss after mini-batch   500: 1.151
# Loss after mini-batch  1000: 1.157
# Loss after mini-batch  1500: 1.154
# Loss after mini-batch  2000: 1.159
# Loss after mini-batch  2500: 1.163
# Loss after mini-batch  3000: 1.164
# (30591, 12)
# (30591, 12)
# Starting epoch 1
# Loss after mini-batch   500: 1.254
# Loss after mini-batch  1000: 1.209
# Loss after mini-batch  1500: 1.194
# Loss after mini-batch  2000: 1.191
# Loss after mini-batch  2500: 1.198
# Loss after mini-batch  3000: 1.203
# Starting epoch 2
# Loss after mini-batch   500: 1.191
# Loss after mini-batch  1000: 1.193
# Loss after mini-batch  1500: 1.193
# Loss after mini-batch  2000: 1.186
# Loss after mini-batch  2500: 1.193
# Loss after mini-batch  3000: 1.177
# Starting epoch 3
# Loss after mini-batch   500: 1.176
# Loss after mini-batch  1000: 1.175
# Loss after mini-batch  1500: 1.188
# Loss after mini-batch  2000: 1.184
# Loss after mini-batch  2500: 1.171
# Loss after mini-batch  3000: 1.197
# Starting epoch 4
# Loss after mini-batch   500: 1.175
# Loss after mini-batch  1000: 1.177
# Loss after mini-batch  1500: 1.179
# Loss after mini-batch  2000: 1.178
# Loss after mini-batch  2500: 1.171
# Loss after mini-batch  3000: 1.186
# Starting epoch 5
# Loss after mini-batch   500: 1.182
# Loss after mini-batch  1000: 1.180
# Loss after mini-batch  1500: 1.178
# Loss after mini-batch  2000: 1.174
# Loss after mini-batch  2500: 1.171
# Loss after mini-batch  3000: 1.173
# Starting epoch 6
# Loss after mini-batch   500: 1.184
# Loss after mini-batch  1000: 1.162
# Loss after mini-batch  1500: 1.170
# Loss after mini-batch  2000: 1.172
# Loss after mini-batch  2500: 1.173
# Loss after mini-batch  3000: 1.179
# Starting epoch 7
# Loss after mini-batch   500: 1.164
# Loss after mini-batch  1000: 1.179
# Loss after mini-batch  1500: 1.171
# Loss after mini-batch  2000: 1.174
# Loss after mini-batch  2500: 1.183
# Loss after mini-batch  3000: 1.164
# Starting epoch 8
# Loss after mini-batch   500: 1.173
# Loss after mini-batch  1000: 1.178
# Loss after mini-batch  1500: 1.173
# Loss after mini-batch  2000: 1.170
# Loss after mini-batch  2500: 1.153
# Loss after mini-batch  3000: 1.177
# Starting epoch 9
# Loss after mini-batch   500: 1.168
# Loss after mini-batch  1000: 1.174
# Loss after mini-batch  1500: 1.179
# Loss after mini-batch  2000: 1.176
# Loss after mini-batch  2500: 1.169
# Loss after mini-batch  3000: 1.163
# Starting epoch 10
# Loss after mini-batch   500: 1.180
# Loss after mini-batch  1000: 1.175
# Loss after mini-batch  1500: 1.183
# Loss after mini-batch  2000: 1.146
# Loss after mini-batch  2500: 1.166
# Loss after mini-batch  3000: 1.174
# Starting epoch 11
# Loss after mini-batch   500: 1.170
# Loss after mini-batch  1000: 1.177
# Loss after mini-batch  1500: 1.180
# Loss after mini-batch  2000: 1.155
# Loss after mini-batch  2500: 1.178
# Loss after mini-batch  3000: 1.175
# Starting epoch 12
# Loss after mini-batch   500: 1.169
# Loss after mini-batch  1000: 1.177
# Loss after mini-batch  1500: 1.170
# Loss after mini-batch  2000: 1.182
# Loss after mini-batch  2500: 1.172
# Loss after mini-batch  3000: 1.156
# Starting epoch 13
# Loss after mini-batch   500: 1.173
# Loss after mini-batch  1000: 1.169
# Loss after mini-batch  1500: 1.177
# Loss after mini-batch  2000: 1.171
# Loss after mini-batch  2500: 1.175
# Loss after mini-batch  3000: 1.163
# Starting epoch 14
# Loss after mini-batch   500: 1.175
# Loss after mini-batch  1000: 1.162
# Loss after mini-batch  1500: 1.168
# Loss after mini-batch  2000: 1.180
# Loss after mini-batch  2500: 1.167
# Loss after mini-batch  3000: 1.175
# Starting epoch 15
# Loss after mini-batch   500: 1.160
# Loss after mini-batch  1000: 1.175
# Loss after mini-batch  1500: 1.155
# Loss after mini-batch  2000: 1.170
# Loss after mini-batch  2500: 1.180
# Loss after mini-batch  3000: 1.184
# Starting epoch 16
# Loss after mini-batch   500: 1.180
# Loss after mini-batch  1000: 1.165
# Loss after mini-batch  1500: 1.162
# Loss after mini-batch  2000: 1.175
# Loss after mini-batch  2500: 1.166
# Loss after mini-batch  3000: 1.177
# Starting epoch 17
# Loss after mini-batch   500: 1.170
# Loss after mini-batch  1000: 1.162
# Loss after mini-batch  1500: 1.169
# Loss after mini-batch  2000: 1.158
# Loss after mini-batch  2500: 1.179
# Loss after mini-batch  3000: 1.181
# Starting epoch 18
# Loss after mini-batch   500: 1.181
# Loss after mini-batch  1000: 1.172
# Loss after mini-batch  1500: 1.171
# Loss after mini-batch  2000: 1.165
# Loss after mini-batch  2500: 1.159
# Loss after mini-batch  3000: 1.176
# Starting epoch 19
# Loss after mini-batch   500: 1.162
# Loss after mini-batch  1000: 1.175
# Loss after mini-batch  1500: 1.171
# Loss after mini-batch  2000: 1.174
# Loss after mini-batch  2500: 1.160
# Loss after mini-batch  3000: 1.176
# Starting epoch 20
# Loss after mini-batch   500: 1.174
# Loss after mini-batch  1000: 1.160
# Loss after mini-batch  1500: 1.177
# Loss after mini-batch  2000: 1.162
# Loss after mini-batch  2500: 1.169
# Loss after mini-batch  3000: 1.178
# Starting epoch 21
# Loss after mini-batch   500: 1.175
# Loss after mini-batch  1000: 1.172
# Loss after mini-batch  1500: 1.174
# Loss after mini-batch  2000: 1.156
# Loss after mini-batch  2500: 1.170
# Loss after mini-batch  3000: 1.168
# Starting epoch 22
# Loss after mini-batch   500: 1.167
# Loss after mini-batch  1000: 1.174
# Loss after mini-batch  1500: 1.157
# Loss after mini-batch  2000: 1.171
# Loss after mini-batch  2500: 1.174
# Loss after mini-batch  3000: 1.169
# Starting epoch 23
# Loss after mini-batch   500: 1.178
# Loss after mini-batch  1000: 1.168
# Loss after mini-batch  1500: 1.163
# Loss after mini-batch  2000: 1.181
# Loss after mini-batch  2500: 1.151
# Loss after mini-batch  3000: 1.175
# Starting epoch 24
# Loss after mini-batch   500: 1.158
# Loss after mini-batch  1000: 1.177
# Loss after mini-batch  1500: 1.180
# Loss after mini-batch  2000: 1.167
# Loss after mini-batch  2500: 1.168
# Loss after mini-batch  3000: 1.166
# Starting epoch 25
# Loss after mini-batch   500: 1.172
# Loss after mini-batch  1000: 1.169
# Loss after mini-batch  1500: 1.164
# Loss after mini-batch  2000: 1.169
# Loss after mini-batch  2500: 1.161
# Loss after mini-batch  3000: 1.177
# Starting epoch 26
# Loss after mini-batch   500: 1.171
# Loss after mini-batch  1000: 1.175
# Loss after mini-batch  1500: 1.161
# Loss after mini-batch  2000: 1.168
# Loss after mini-batch  2500: 1.173
# Loss after mini-batch  3000: 1.164
# Starting epoch 27
# Loss after mini-batch   500: 1.163
# Loss after mini-batch  1000: 1.172
# Loss after mini-batch  1500: 1.161
# Loss after mini-batch  2000: 1.166
# Loss after mini-batch  2500: 1.178
# Loss after mini-batch  3000: 1.174
# Starting epoch 28
# Loss after mini-batch   500: 1.169
# Loss after mini-batch  1000: 1.163
# Loss after mini-batch  1500: 1.173
# Loss after mini-batch  2000: 1.169
# Loss after mini-batch  2500: 1.173
# Loss after mini-batch  3000: 1.167
# Starting epoch 29
# Loss after mini-batch   500: 1.169
# Loss after mini-batch  1000: 1.170
# Loss after mini-batch  1500: 1.184
# Loss after mini-batch  2000: 1.153
# Loss after mini-batch  2500: 1.160
# Loss after mini-batch  3000: 1.171
# Starting epoch 30
# Loss after mini-batch   500: 1.154
# Loss after mini-batch  1000: 1.173
# Loss after mini-batch  1500: 1.183
# Loss after mini-batch  2000: 1.173
# Loss after mini-batch  2500: 1.160
# Loss after mini-batch  3000: 1.163
# Starting epoch 31
# Loss after mini-batch   500: 1.158
# Loss after mini-batch  1000: 1.174
# Loss after mini-batch  1500: 1.170
# Loss after mini-batch  2000: 1.161
# Loss after mini-batch  2500: 1.170
# Loss after mini-batch  3000: 1.173
# Starting epoch 32
# Loss after mini-batch   500: 1.161
# Loss after mini-batch  1000: 1.174
# Loss after mini-batch  1500: 1.162
# Loss after mini-batch  2000: 1.168
# Loss after mini-batch  2500: 1.171
# Loss after mini-batch  3000: 1.169
# Starting epoch 33
# Loss after mini-batch   500: 1.169
# Loss after mini-batch  1000: 1.177
# Loss after mini-batch  1500: 1.160
# Loss after mini-batch  2000: 1.179
# Loss after mini-batch  2500: 1.152
# Loss after mini-batch  3000: 1.167
# Starting epoch 34
# Loss after mini-batch   500: 1.173
# Loss after mini-batch  1000: 1.168
# Loss after mini-batch  1500: 1.158
# Loss after mini-batch  2000: 1.161
# Loss after mini-batch  2500: 1.164
# Loss after mini-batch  3000: 1.182
# Starting epoch 35
# Loss after mini-batch   500: 1.165
# Loss after mini-batch  1000: 1.168
# Loss after mini-batch  1500: 1.169
# Loss after mini-batch  2000: 1.167
# Loss after mini-batch  2500: 1.178
# Loss after mini-batch  3000: 1.154
# Starting epoch 36
# Loss after mini-batch   500: 1.163
# Loss after mini-batch  1000: 1.179
# Loss after mini-batch  1500: 1.163
# Loss after mini-batch  2000: 1.167
# Loss after mini-batch  2500: 1.180
# Loss after mini-batch  3000: 1.157
# Starting epoch 37
# Loss after mini-batch   500: 1.154
# Loss after mini-batch  1000: 1.162
# Loss after mini-batch  1500: 1.177
# Loss after mini-batch  2000: 1.162
# Loss after mini-batch  2500: 1.173
# Loss after mini-batch  3000: 1.177
# Starting epoch 38
# Loss after mini-batch   500: 1.168
# Loss after mini-batch  1000: 1.170
# Loss after mini-batch  1500: 1.164
# Loss after mini-batch  2000: 1.174
# Loss after mini-batch  2500: 1.166
# Loss after mini-batch  3000: 1.158
# Starting epoch 39
# Loss after mini-batch   500: 1.160
# Loss after mini-batch  1000: 1.161
# Loss after mini-batch  1500: 1.185
# Loss after mini-batch  2000: 1.177
# Loss after mini-batch  2500: 1.168
# Loss after mini-batch  3000: 1.152
# Starting epoch 40
# Loss after mini-batch   500: 1.179
# Loss after mini-batch  1000: 1.145
# Loss after mini-batch  1500: 1.183
# Loss after mini-batch  2000: 1.177
# Loss after mini-batch  2500: 1.164
# Loss after mini-batch  3000: 1.159
# Starting epoch 41
# Loss after mini-batch   500: 1.167
# Loss after mini-batch  1000: 1.173
# Loss after mini-batch  1500: 1.149
# Loss after mini-batch  2000: 1.179
# Loss after mini-batch  2500: 1.172
# Loss after mini-batch  3000: 1.164
# Starting epoch 42
# Loss after mini-batch   500: 1.176
# Loss after mini-batch  1000: 1.163
# Loss after mini-batch  1500: 1.159
# Loss after mini-batch  2000: 1.174
# Loss after mini-batch  2500: 1.165
# Loss after mini-batch  3000: 1.163
# Starting epoch 43
# Loss after mini-batch   500: 1.161
# Loss after mini-batch  1000: 1.170
# Loss after mini-batch  1500: 1.169
# Loss after mini-batch  2000: 1.151
# Loss after mini-batch  2500: 1.179
# Loss after mini-batch  3000: 1.162
# Starting epoch 44
# Loss after mini-batch   500: 1.175
# Loss after mini-batch  1000: 1.176
# Loss after mini-batch  1500: 1.171
# Loss after mini-batch  2000: 1.152
# Loss after mini-batch  2500: 1.154
# Loss after mini-batch  3000: 1.168
# Starting epoch 45
# Loss after mini-batch   500: 1.180
# Loss after mini-batch  1000: 1.161
# Loss after mini-batch  1500: 1.150
# Loss after mini-batch  2000: 1.170
# Loss after mini-batch  2500: 1.160
# Loss after mini-batch  3000: 1.172
# Starting epoch 46
# Loss after mini-batch   500: 1.158
# Loss after mini-batch  1000: 1.163
# Loss after mini-batch  1500: 1.177
# Loss after mini-batch  2000: 1.154
# Loss after mini-batch  2500: 1.170
# Loss after mini-batch  3000: 1.168
# Starting epoch 47
# Loss after mini-batch   500: 1.155
# Loss after mini-batch  1000: 1.179
# Loss after mini-batch  1500: 1.169
# Loss after mini-batch  2000: 1.168
# Loss after mini-batch  2500: 1.163
# Loss after mini-batch  3000: 1.165
# Starting epoch 48
# Loss after mini-batch   500: 1.159
# Loss after mini-batch  1000: 1.176
# Loss after mini-batch  1500: 1.155
# Loss after mini-batch  2000: 1.155
# Loss after mini-batch  2500: 1.160
# Loss after mini-batch  3000: 1.186
# Starting epoch 49
# Loss after mini-batch   500: 1.184
# Loss after mini-batch  1000: 1.161
# Loss after mini-batch  1500: 1.154
# Loss after mini-batch  2000: 1.162
# Loss after mini-batch  2500: 1.164
# Loss after mini-batch  3000: 1.174
# Starting epoch 50
# Loss after mini-batch   500: 1.166
# Loss after mini-batch  1000: 1.162
# Loss after mini-batch  1500: 1.177
# Loss after mini-batch  2000: 1.168
# Loss after mini-batch  2500: 1.157
# Loss after mini-batch  3000: 1.164
# (30591, 13)
# (30591, 13)
# Starting epoch 1
# Loss after mini-batch   500: 1.259
# Loss after mini-batch  1000: 1.222
# Loss after mini-batch  1500: 1.204
# Loss after mini-batch  2000: 1.206
# Loss after mini-batch  2500: 1.191
# Loss after mini-batch  3000: 1.185
# Starting epoch 2
# Loss after mini-batch   500: 1.195
# Loss after mini-batch  1000: 1.185
# Loss after mini-batch  1500: 1.204
# Loss after mini-batch  2000: 1.191
# Loss after mini-batch  2500: 1.198
# Loss after mini-batch  3000: 1.200
# Starting epoch 3
# Loss after mini-batch   500: 1.191
# Loss after mini-batch  1000: 1.194
# Loss after mini-batch  1500: 1.191
# Loss after mini-batch  2000: 1.194
# Loss after mini-batch  2500: 1.195
# Loss after mini-batch  3000: 1.183
# Starting epoch 4
# Loss after mini-batch   500: 1.180
# Loss after mini-batch  1000: 1.183
# Loss after mini-batch  1500: 1.189
# Loss after mini-batch  2000: 1.184
# Loss after mini-batch  2500: 1.198
# Loss after mini-batch  3000: 1.193
# Starting epoch 5
# Loss after mini-batch   500: 1.175
# Loss after mini-batch  1000: 1.191
# Loss after mini-batch  1500: 1.191
# Loss after mini-batch  2000: 1.184
# Loss after mini-batch  2500: 1.176
# Loss after mini-batch  3000: 1.189
# Starting epoch 6
# Loss after mini-batch   500: 1.178
# Loss after mini-batch  1000: 1.189
# Loss after mini-batch  1500: 1.189
# Loss after mini-batch  2000: 1.172
# Loss after mini-batch  2500: 1.177
# Loss after mini-batch  3000: 1.189
# Starting epoch 7
# Loss after mini-batch   500: 1.194
# Loss after mini-batch  1000: 1.165
# Loss after mini-batch  1500: 1.179
# Loss after mini-batch  2000: 1.185
# Loss after mini-batch  2500: 1.182
# Loss after mini-batch  3000: 1.178
# Starting epoch 8
# Loss after mini-batch   500: 1.181
# Loss after mini-batch  1000: 1.185
# Loss after mini-batch  1500: 1.168
# Loss after mini-batch  2000: 1.184
# Loss after mini-batch  2500: 1.179
# Loss after mini-batch  3000: 1.177
# Starting epoch 9
# Loss after mini-batch   500: 1.162
# Loss after mini-batch  1000: 1.183
# Loss after mini-batch  1500: 1.178
# Loss after mini-batch  2000: 1.180
# Loss after mini-batch  2500: 1.183
# Loss after mini-batch  3000: 1.188
# Starting epoch 10
# Loss after mini-batch   500: 1.179
# Loss after mini-batch  1000: 1.172
# Loss after mini-batch  1500: 1.167
# Loss after mini-batch  2000: 1.191
# Loss after mini-batch  2500: 1.174
# Loss after mini-batch  3000: 1.176
# Starting epoch 11
# Loss after mini-batch   500: 1.177
# Loss after mini-batch  1000: 1.175
# Loss after mini-batch  1500: 1.174
# Loss after mini-batch  2000: 1.172
# Loss after mini-batch  2500: 1.192
# Loss after mini-batch  3000: 1.176
# Starting epoch 12
# Loss after mini-batch   500: 1.174
# Loss after mini-batch  1000: 1.184
# Loss after mini-batch  1500: 1.179
# Loss after mini-batch  2000: 1.175
# Loss after mini-batch  2500: 1.176
# Loss after mini-batch  3000: 1.168
# Starting epoch 13
# Loss after mini-batch   500: 1.175
# Loss after mini-batch  1000: 1.188
# Loss after mini-batch  1500: 1.171
# Loss after mini-batch  2000: 1.180
# Loss after mini-batch  2500: 1.172
# Loss after mini-batch  3000: 1.172
# Starting epoch 14
# Loss after mini-batch   500: 1.177
# Loss after mini-batch  1000: 1.165
# Loss after mini-batch  1500: 1.186
# Loss after mini-batch  2000: 1.175
# Loss after mini-batch  2500: 1.180
# Loss after mini-batch  3000: 1.173
# Starting epoch 15
# Loss after mini-batch   500: 1.173
# Loss after mini-batch  1000: 1.187
# Loss after mini-batch  1500: 1.172
# Loss after mini-batch  2000: 1.173
# Loss after mini-batch  2500: 1.178
# Loss after mini-batch  3000: 1.171
# Starting epoch 16
# Loss after mini-batch   500: 1.171
# Loss after mini-batch  1000: 1.167
# Loss after mini-batch  1500: 1.184
# Loss after mini-batch  2000: 1.172
# Loss after mini-batch  2500: 1.184
# Loss after mini-batch  3000: 1.175
# Starting epoch 17
# Loss after mini-batch   500: 1.178
# Loss after mini-batch  1000: 1.182
# Loss after mini-batch  1500: 1.184
# Loss after mini-batch  2000: 1.169
# Loss after mini-batch  2500: 1.170
# Loss after mini-batch  3000: 1.167
# Starting epoch 18
# Loss after mini-batch   500: 1.178
# Loss after mini-batch  1000: 1.169
# Loss after mini-batch  1500: 1.177
# Loss after mini-batch  2000: 1.175
# Loss after mini-batch  2500: 1.188
# Loss after mini-batch  3000: 1.163
# Starting epoch 19
# Loss after mini-batch   500: 1.193
# Loss after mini-batch  1000: 1.156
# Loss after mini-batch  1500: 1.169
# Loss after mini-batch  2000: 1.168
# Loss after mini-batch  2500: 1.172
# Loss after mini-batch  3000: 1.188
# Starting epoch 20
# Loss after mini-batch   500: 1.181
# Loss after mini-batch  1000: 1.169
# Loss after mini-batch  1500: 1.177
# Loss after mini-batch  2000: 1.172
# Loss after mini-batch  2500: 1.176
# Loss after mini-batch  3000: 1.169
# Starting epoch 21
# Loss after mini-batch   500: 1.170
# Loss after mini-batch  1000: 1.168
# Loss after mini-batch  1500: 1.166
# Loss after mini-batch  2000: 1.185
# Loss after mini-batch  2500: 1.174
# Loss after mini-batch  3000: 1.174
# Starting epoch 22
# Loss after mini-batch   500: 1.158
# Loss after mini-batch  1000: 1.167
# Loss after mini-batch  1500: 1.179
# Loss after mini-batch  2000: 1.180
# Loss after mini-batch  2500: 1.180
# Loss after mini-batch  3000: 1.182
# Starting epoch 23
# Loss after mini-batch   500: 1.167
# Loss after mini-batch  1000: 1.179
# Loss after mini-batch  1500: 1.164
# Loss after mini-batch  2000: 1.184
# Loss after mini-batch  2500: 1.176
# Loss after mini-batch  3000: 1.169
# Starting epoch 24
# Loss after mini-batch   500: 1.172
# Loss after mini-batch  1000: 1.182
# Loss after mini-batch  1500: 1.180
# Loss after mini-batch  2000: 1.174
# Loss after mini-batch  2500: 1.168
# Loss after mini-batch  3000: 1.167
# Starting epoch 25
# Loss after mini-batch   500: 1.165
# Loss after mini-batch  1000: 1.179
# Loss after mini-batch  1500: 1.172
# Loss after mini-batch  2000: 1.170
# Loss after mini-batch  2500: 1.181
# Loss after mini-batch  3000: 1.175
# Starting epoch 26
# Loss after mini-batch   500: 1.173
# Loss after mini-batch  1000: 1.165
# Loss after mini-batch  1500: 1.168
# Loss after mini-batch  2000: 1.174
# Loss after mini-batch  2500: 1.184
# Loss after mini-batch  3000: 1.177
# Starting epoch 27
# Loss after mini-batch   500: 1.168
# Loss after mini-batch  1000: 1.177
# Loss after mini-batch  1500: 1.167
# Loss after mini-batch  2000: 1.183
# Loss after mini-batch  2500: 1.183
# Loss after mini-batch  3000: 1.158
# Starting epoch 28
# Loss after mini-batch   500: 1.168
# Loss after mini-batch  1000: 1.171
# Loss after mini-batch  1500: 1.176
# Loss after mini-batch  2000: 1.180
# Loss after mini-batch  2500: 1.170
# Loss after mini-batch  3000: 1.174
# Starting epoch 29
# Loss after mini-batch   500: 1.159
# Loss after mini-batch  1000: 1.172
# Loss after mini-batch  1500: 1.173
# Loss after mini-batch  2000: 1.180
# Loss after mini-batch  2500: 1.174
# Loss after mini-batch  3000: 1.177
# Starting epoch 30
# Loss after mini-batch   500: 1.176
# Loss after mini-batch  1000: 1.179
# Loss after mini-batch  1500: 1.164
# Loss after mini-batch  2000: 1.178
# Loss after mini-batch  2500: 1.166
# Loss after mini-batch  3000: 1.175
# Starting epoch 31
# Loss after mini-batch   500: 1.167
# Loss after mini-batch  1000: 1.160
# Loss after mini-batch  1500: 1.174
# Loss after mini-batch  2000: 1.182
# Loss after mini-batch  2500: 1.180
# Loss after mini-batch  3000: 1.167
# Starting epoch 32
# Loss after mini-batch   500: 1.174
# Loss after mini-batch  1000: 1.160
# Loss after mini-batch  1500: 1.168
# Loss after mini-batch  2000: 1.179
# Loss after mini-batch  2500: 1.186
# Loss after mini-batch  3000: 1.164
# Starting epoch 33
# Loss after mini-batch   500: 1.178
# Loss after mini-batch  1000: 1.158
# Loss after mini-batch  1500: 1.169
# Loss after mini-batch  2000: 1.171
# Loss after mini-batch  2500: 1.183
# Loss after mini-batch  3000: 1.177
# Starting epoch 34
# Loss after mini-batch   500: 1.178
# Loss after mini-batch  1000: 1.168
# Loss after mini-batch  1500: 1.168
# Loss after mini-batch  2000: 1.167
# Loss after mini-batch  2500: 1.167
# Loss after mini-batch  3000: 1.184
# Starting epoch 35
# Loss after mini-batch   500: 1.161
# Loss after mini-batch  1000: 1.174
# Loss after mini-batch  1500: 1.173
# Loss after mini-batch  2000: 1.163
# Loss after mini-batch  2500: 1.172
# Loss after mini-batch  3000: 1.185
# Starting epoch 36
# Loss after mini-batch   500: 1.178
# Loss after mini-batch  1000: 1.163
# Loss after mini-batch  1500: 1.180
# Loss after mini-batch  2000: 1.179
# Loss after mini-batch  2500: 1.170
# Loss after mini-batch  3000: 1.165
# Starting epoch 37
# Loss after mini-batch   500: 1.161
# Loss after mini-batch  1000: 1.177
# Loss after mini-batch  1500: 1.168
# Loss after mini-batch  2000: 1.172
# Loss after mini-batch  2500: 1.168
# Loss after mini-batch  3000: 1.179
# Starting epoch 38
# Loss after mini-batch   500: 1.170
# Loss after mini-batch  1000: 1.175
# Loss after mini-batch  1500: 1.178
# Loss after mini-batch  2000: 1.173
# Loss after mini-batch  2500: 1.165
# Loss after mini-batch  3000: 1.170
# Starting epoch 39
# Loss after mini-batch   500: 1.179
# Loss after mini-batch  1000: 1.181
# Loss after mini-batch  1500: 1.175
# Loss after mini-batch  2000: 1.169
# Loss after mini-batch  2500: 1.165
# Loss after mini-batch  3000: 1.166
# Starting epoch 40
# Loss after mini-batch   500: 1.171
# Loss after mini-batch  1000: 1.168
# Loss after mini-batch  1500: 1.175
# Loss after mini-batch  2000: 1.177
# Loss after mini-batch  2500: 1.165
# Loss after mini-batch  3000: 1.173
# Starting epoch 41
# Loss after mini-batch   500: 1.177
# Loss after mini-batch  1000: 1.171
# Loss after mini-batch  1500: 1.179
# Loss after mini-batch  2000: 1.163
# Loss after mini-batch  2500: 1.171
# Loss after mini-batch  3000: 1.162
# Starting epoch 42
# Loss after mini-batch   500: 1.174
# Loss after mini-batch  1000: 1.177
# Loss after mini-batch  1500: 1.163
# Loss after mini-batch  2000: 1.175
# Loss after mini-batch  2500: 1.172
# Loss after mini-batch  3000: 1.172
# Starting epoch 43
# Loss after mini-batch   500: 1.179
# Loss after mini-batch  1000: 1.155
# Loss after mini-batch  1500: 1.166
# Loss after mini-batch  2000: 1.177
# Loss after mini-batch  2500: 1.182
# Loss after mini-batch  3000: 1.165
# Starting epoch 44
# Loss after mini-batch   500: 1.168
# Loss after mini-batch  1000: 1.170
# Loss after mini-batch  1500: 1.169
# Loss after mini-batch  2000: 1.159
# Loss after mini-batch  2500: 1.179
# Loss after mini-batch  3000: 1.173
# Starting epoch 45
# Loss after mini-batch   500: 1.168
# Loss after mini-batch  1000: 1.165
# Loss after mini-batch  1500: 1.174
# Loss after mini-batch  2000: 1.176
# Loss after mini-batch  2500: 1.168
# Loss after mini-batch  3000: 1.170
# Starting epoch 46
# Loss after mini-batch   500: 1.179
# Loss after mini-batch  1000: 1.165
# Loss after mini-batch  1500: 1.169
# Loss after mini-batch  2000: 1.167
# Loss after mini-batch  2500: 1.179
# Loss after mini-batch  3000: 1.163
# Starting epoch 47
# Loss after mini-batch   500: 1.167
# Loss after mini-batch  1000: 1.171
# Loss after mini-batch  1500: 1.167
# Loss after mini-batch  2000: 1.168
# Loss after mini-batch  2500: 1.172
# Loss after mini-batch  3000: 1.173
# Starting epoch 48
# Loss after mini-batch   500: 1.183
# Loss after mini-batch  1000: 1.159
# Loss after mini-batch  1500: 1.169
# Loss after mini-batch  2000: 1.175
# Loss after mini-batch  2500: 1.158
# Loss after mini-batch  3000: 1.178
# Starting epoch 49
# Loss after mini-batch   500: 1.161
# Loss after mini-batch  1000: 1.176
# Loss after mini-batch  1500: 1.172
# Loss after mini-batch  2000: 1.166
# Loss after mini-batch  2500: 1.160
# Loss after mini-batch  3000: 1.188
# Starting epoch 50
# Loss after mini-batch   500: 1.168
# Loss after mini-batch  1000: 1.173
# Loss after mini-batch  1500: 1.179
# Loss after mini-batch  2000: 1.153
# Loss after mini-batch  2500: 1.178
# Loss after mini-batch  3000: 1.170
# (30591, 14)
# (30591, 14)
# Starting epoch 1
# Loss after mini-batch   500: 1.292
# Loss after mini-batch  1000: 1.200
# Loss after mini-batch  1500: 1.208
# Loss after mini-batch  2000: 1.185
# Loss after mini-batch  2500: 1.191
# Loss after mini-batch  3000: 1.197
# Starting epoch 2
# Loss after mini-batch   500: 1.187
# Loss after mini-batch  1000: 1.187
# Loss after mini-batch  1500: 1.193
# Loss after mini-batch  2000: 1.188
# Loss after mini-batch  2500: 1.197
# Loss after mini-batch  3000: 1.195
# Starting epoch 3
# Loss after mini-batch   500: 1.184
# Loss after mini-batch  1000: 1.179
# Loss after mini-batch  1500: 1.200
# Loss after mini-batch  2000: 1.185
# Loss after mini-batch  2500: 1.187
# Loss after mini-batch  3000: 1.194
# Starting epoch 4
# Loss after mini-batch   500: 1.188
# Loss after mini-batch  1000: 1.190
# Loss after mini-batch  1500: 1.182
# Loss after mini-batch  2000: 1.197
# Loss after mini-batch  2500: 1.173
# Loss after mini-batch  3000: 1.179
# Starting epoch 5
# Loss after mini-batch   500: 1.167
# Loss after mini-batch  1000: 1.192
# Loss after mini-batch  1500: 1.193
# Loss after mini-batch  2000: 1.178
# Loss after mini-batch  2500: 1.181
# Loss after mini-batch  3000: 1.185
# Starting epoch 6
# Loss after mini-batch   500: 1.177
# Loss after mini-batch  1000: 1.169
# Loss after mini-batch  1500: 1.179
# Loss after mini-batch  2000: 1.180
# Loss after mini-batch  2500: 1.186
# Loss after mini-batch  3000: 1.182
# Starting epoch 7
# Loss after mini-batch   500: 1.180
# Loss after mini-batch  1000: 1.174
# Loss after mini-batch  1500: 1.170
# Loss after mini-batch  2000: 1.178
# Loss after mini-batch  2500: 1.178
# Loss after mini-batch  3000: 1.178
# Starting epoch 8
# Loss after mini-batch   500: 1.173
# Loss after mini-batch  1000: 1.171
# Loss after mini-batch  1500: 1.184
# Loss after mini-batch  2000: 1.178
# Loss after mini-batch  2500: 1.171
# Loss after mini-batch  3000: 1.181
# Starting epoch 9
# Loss after mini-batch   500: 1.171
# Loss after mini-batch  1000: 1.169
# Loss after mini-batch  1500: 1.183
# Loss after mini-batch  2000: 1.177
# Loss after mini-batch  2500: 1.165
# Loss after mini-batch  3000: 1.187
# Starting epoch 10
# Loss after mini-batch   500: 1.180
# Loss after mini-batch  1000: 1.175
# Loss after mini-batch  1500: 1.177
# Loss after mini-batch  2000: 1.169
# Loss after mini-batch  2500: 1.162
# Loss after mini-batch  3000: 1.185
# Starting epoch 11
# ...
# Starting epoch 35
# Loss after mini-batch   500: 1.131
# Loss after mini-batch  1000: 1.143
# Loss after mini-batch  1500: 1.126
# Loss after mini-batch  2000: 1.113
# Loss after mini-batch  2500: 1.141
# Loss after mini-batch  3000: 1.133
# Starting epoch 36
# Loss after mini-batch   500: 1.126
# Loss after mini-batch  1000: 1.133
# Loss after mini-batch  1500: 1.132
# Loss after mini-batch  2000: 1.138
# Loss after mini-batch  2500: 1.124
# Loss after mini-batch  3000: 1.120
# Starting epoch 37
# Loss after mini-batch   500: 1.136
# Loss after mini-batch  1000: 1.127
# Loss after mini-batch  1500: 1.116
# Loss after mini-batch  2000: 1.135
# Loss after mini-batch  2500: 1.130
# Loss after mini-batch  3000: 1.133
# Starting epoch 38
# Loss after mini-batch   500: 1.117
# Loss after mini-batch  1000: 1.127
# Loss after mini-batch  1500: 1.135
# Loss after mini-batch  2000: 1.132
# Loss after mini-batch  2500: 1.127
# Loss after mini-batch  3000: 1.136
# Starting epoch 39
# Loss after mini-batch   500: 1.124
# Loss after mini-batch  1000: 1.114
# Loss after mini-batch  1500: 1.145
# Loss after mini-batch  2000: 1.118
# Loss after mini-batch  2500: 1.124
# Loss after mini-batch  3000: 1.143
# Starting epoch 40
# Loss after mini-batch   500: 1.119
# Loss after mini-batch  1000: 1.138
# Loss after mini-batch  1500: 1.130
# Loss after mini-batch  2000: 1.121
# Loss after mini-batch  2500: 1.131
# Loss after mini-batch  3000: 1.127
# Starting epoch 41
# Loss after mini-batch   500: 1.112
# Loss after mini-batch  1000: 1.120
# Loss after mini-batch  1500: 1.118
# Loss after mini-batch  2000: 1.137
# Loss after mini-batch  2500: 1.127
# Loss after mini-batch  3000: 1.143
# Starting epoch 42
# Loss after mini-batch   500: 1.120
# Loss after mini-batch  1000: 1.134
# Loss after mini-batch  1500: 1.106
# Loss after mini-batch  2000: 1.136
# Loss after mini-batch  2500: 1.133
# Loss after mini-batch  3000: 1.135
# Starting epoch 43
# Loss after mini-batch   500: 1.131
# Loss after mini-batch  1000: 1.122
# Loss after mini-batch  1500: 1.109
# Loss after mini-batch  2000: 1.128
# Loss after mini-batch  2500: 1.144
# Loss after mini-batch  3000: 1.120
# Starting epoch 44
# Loss after mini-batch   500: 1.108
# Loss after mini-batch  1000: 1.127
# Loss after mini-batch  1500: 1.127
# Loss after mini-batch  2000: 1.124
# Loss after mini-batch  2500: 1.131
# Loss after mini-batch  3000: 1.128
# Starting epoch 45
# Loss after mini-batch   500: 1.122
# Loss after mini-batch  1000: 1.127
# Loss after mini-batch  1500: 1.119
# Loss after mini-batch  2000: 1.127
# Loss after mini-batch  2500: 1.128
# Loss after mini-batch  3000: 1.124
# Starting epoch 46
# Loss after mini-batch   500: 1.116
# Loss after mini-batch  1000: 1.136
# Loss after mini-batch  1500: 1.126
# Loss after mini-batch  2000: 1.121
# Loss after mini-batch  2500: 1.117
# Loss after mini-batch  3000: 1.121
# Starting epoch 47
# Loss after mini-batch   500: 1.114
# Loss after mini-batch  1000: 1.137
# Loss after mini-batch  1500: 1.130
# Loss after mini-batch  2000: 1.110
# Loss after mini-batch  2500: 1.116
# Loss after mini-batch  3000: 1.131
# Starting epoch 48
# Loss after mini-batch   500: 1.128
# Loss after mini-batch  1000: 1.127
# Loss after mini-batch  1500: 1.117
# Loss after mini-batch  2000: 1.122
# Loss after mini-batch  2500: 1.117
# Loss after mini-batch  3000: 1.130
# Starting epoch 49
# Loss after mini-batch   500: 1.123
# Loss after mini-batch  1000: 1.128
# Loss after mini-batch  1500: 1.120
# Loss after mini-batch  2000: 1.131
# Loss after mini-batch  2500: 1.116
# Loss after mini-batch  3000: 1.108
# Starting epoch 50
# Loss after mini-batch   500: 1.110
# Loss after mini-batch  1000: 1.117
# Loss after mini-batch  1500: 1.120
# Loss after mini-batch  2000: 1.126
# Loss after mini-batch  2500: 1.110
# Loss after mini-batch  3000: 1.148
# (30591, 37)
# (30591, 37)
# Starting epoch 1
# Loss after mini-batch   500: 1.296
# Loss after mini-batch  1000: 1.184
# Loss after mini-batch  1500: 1.176
# Loss after mini-batch  2000: 1.184
# Loss after mini-batch  2500: 1.179
# Loss after mini-batch  3000: 1.192
# Starting epoch 2
# Loss after mini-batch   500: 1.167
# Loss after mini-batch  1000: 1.189
# Loss after mini-batch  1500: 1.165
# Loss after mini-batch  2000: 1.175
# Loss after mini-batch  2500: 1.167
# Loss after mini-batch  3000: 1.173
# Starting epoch 3
# Loss after mini-batch   500: 1.180
# Loss after mini-batch  1000: 1.181
# Loss after mini-batch  1500: 1.156
# Loss after mini-batch  2000: 1.165
# Loss after mini-batch  2500: 1.161
# Loss after mini-batch  3000: 1.161
# Starting epoch 4
# Loss after mini-batch   500: 1.158
# Loss after mini-batch  1000: 1.163
# Loss after mini-batch  1500: 1.164
# Loss after mini-batch  2000: 1.164
# Loss after mini-batch  2500: 1.167
# Loss after mini-batch  3000: 1.169
# Starting epoch 5
# Loss after mini-batch   500: 1.153
# Loss after mini-batch  1000: 1.154
# Loss after mini-batch  1500: 1.164
# Loss after mini-batch  2000: 1.157
# Loss after mini-batch  2500: 1.162
# Loss after mini-batch  3000: 1.173
# Starting epoch 6
# Loss after mini-batch   500: 1.149
# Loss after mini-batch  1000: 1.170
# Loss after mini-batch  1500: 1.156
# Loss after mini-batch  2000: 1.157
# Loss after mini-batch  2500: 1.155
# Loss after mini-batch  3000: 1.155
# Starting epoch 7
# Loss after mini-batch   500: 1.151
# Loss after mini-batch  1000: 1.151
# Loss after mini-batch  1500: 1.172
# Loss after mini-batch  2000: 1.158
# Loss after mini-batch  2500: 1.132
# Loss after mini-batch  3000: 1.153
# Starting epoch 8
# Loss after mini-batch   500: 1.155
# Loss after mini-batch  1000: 1.151
# Loss after mini-batch  1500: 1.153
# Loss after mini-batch  2000: 1.147
# Loss after mini-batch  2500: 1.166
# Loss after mini-batch  3000: 1.141
# Starting epoch 9
# Loss after mini-batch   500: 1.167
# Loss after mini-batch  1000: 1.138
# Loss after mini-batch  1500: 1.151
# Loss after mini-batch  2000: 1.140
# Loss after mini-batch  2500: 1.123
# Loss after mini-batch  3000: 1.173
# Starting epoch 10
# Loss after mini-batch   500: 1.146
# Loss after mini-batch  1000: 1.151
# Loss after mini-batch  1500: 1.145
# Loss after mini-batch  2000: 1.148
# Loss after mini-batch  2500: 1.145
# Loss after mini-batch  3000: 1.153
# Starting epoch 11
# Loss after mini-batch   500: 1.145
# Loss after mini-batch  1000: 1.150
# Loss after mini-batch  1500: 1.155
# Loss after mini-batch  2000: 1.145
# Loss after mini-batch  2500: 1.150
# Loss after mini-batch  3000: 1.145
# Starting epoch 12
# Loss after mini-batch   500: 1.135
# Loss after mini-batch  1000: 1.158
# Loss after mini-batch  1500: 1.145
# Loss after mini-batch  2000: 1.152
# Loss after mini-batch  2500: 1.138
# Loss after mini-batch  3000: 1.141
# Starting epoch 13
# Loss after mini-batch   500: 1.151
# Loss after mini-batch  1000: 1.161
# Loss after mini-batch  1500: 1.137
# Loss after mini-batch  2000: 1.143
# Loss after mini-batch  2500: 1.135
# Loss after mini-batch  3000: 1.139
# Starting epoch 14
# Loss after mini-batch   500: 1.129
# Loss after mini-batch  1000: 1.147
# Loss after mini-batch  1500: 1.130
# Loss after mini-batch  2000: 1.147
# Loss after mini-batch  2500: 1.154
# Loss after mini-batch  3000: 1.153
# Starting epoch 15
# Loss after mini-batch   500: 1.134
# Loss after mini-batch  1000: 1.127
# Loss after mini-batch  1500: 1.147
# Loss after mini-batch  2000: 1.155
# Loss after mini-batch  2500: 1.143
# Loss after mini-batch  3000: 1.142
# Starting epoch 16
# Loss after mini-batch   500: 1.145
# Loss after mini-batch  1000: 1.136
# Loss after mini-batch  1500: 1.144
# Loss after mini-batch  2000: 1.155
# Loss after mini-batch  2500: 1.146
# Loss after mini-batch  3000: 1.120
# Starting epoch 17
# Loss after mini-batch   500: 1.137
# Loss after mini-batch  1000: 1.151
# Loss after mini-batch  1500: 1.141
# Loss after mini-batch  2000: 1.137
# Loss after mini-batch  2500: 1.129
# Loss after mini-batch  3000: 1.137
# Starting epoch 18
# Loss after mini-batch   500: 1.131
# Loss after mini-batch  1000: 1.138
# Loss after mini-batch  1500: 1.132
# Loss after mini-batch  2000: 1.154
# Loss after mini-batch  2500: 1.141
# Loss after mini-batch  3000: 1.137
# Starting epoch 19
# Loss after mini-batch   500: 1.125
# Loss after mini-batch  1000: 1.140
# Loss after mini-batch  1500: 1.135
# Loss after mini-batch  2000: 1.146
# Loss after mini-batch  2500: 1.128
# Loss after mini-batch  3000: 1.152
# Starting epoch 20
# Loss after mini-batch   500: 1.130
# Loss after mini-batch  1000: 1.139
# Loss after mini-batch  1500: 1.139
# Loss after mini-batch  2000: 1.137
# Loss after mini-batch  2500: 1.128
# Loss after mini-batch  3000: 1.142
# Starting epoch 21
# Loss after mini-batch   500: 1.130
# Loss after mini-batch  1000: 1.135
# Loss after mini-batch  1500: 1.133
# Loss after mini-batch  2000: 1.126
# Loss after mini-batch  2500: 1.142
# Loss after mini-batch  3000: 1.140
# Starting epoch 22
# Loss after mini-batch   500: 1.137
# Loss after mini-batch  1000: 1.134
# Loss after mini-batch  1500: 1.125
# Loss after mini-batch  2000: 1.140
# Loss after mini-batch  2500: 1.122
# Loss after mini-batch  3000: 1.143
# Starting epoch 23
# Loss after mini-batch   500: 1.141
# Loss after mini-batch  1000: 1.118
# Loss after mini-batch  1500: 1.131
# Loss after mini-batch  2000: 1.136
# Loss after mini-batch  2500: 1.141
# Loss after mini-batch  3000: 1.131
# Starting epoch 24
# Loss after mini-batch   500: 1.127
# Loss after mini-batch  1000: 1.137
# Loss after mini-batch  1500: 1.137
# Loss after mini-batch  2000: 1.134
# Loss after mini-batch  2500: 1.126
# Loss after mini-batch  3000: 1.138
# Starting epoch 25
# Loss after mini-batch   500: 1.128
# Loss after mini-batch  1000: 1.138
# Loss after mini-batch  1500: 1.122
# Loss after mini-batch  2000: 1.134
# Loss after mini-batch  2500: 1.138
# Loss after mini-batch  3000: 1.132
# Starting epoch 26
# Loss after mini-batch   500: 1.127
# Loss after mini-batch  1000: 1.130
# Loss after mini-batch  1500: 1.124
# Loss after mini-batch  2000: 1.127
# Loss after mini-batch  2500: 1.143
# Loss after mini-batch  3000: 1.133
# Starting epoch 27
# Loss after mini-batch   500: 1.139
# Loss after mini-batch  1000: 1.136
# Loss after mini-batch  1500: 1.114
# Loss after mini-batch  2000: 1.138
# Loss after mini-batch  2500: 1.129
# Loss after mini-batch  3000: 1.133
# Starting epoch 28
# Loss after mini-batch   500: 1.138
# Loss after mini-batch  1000: 1.114
# Loss after mini-batch  1500: 1.143
# Loss after mini-batch  2000: 1.134
# Loss after mini-batch  2500: 1.126
# Loss after mini-batch  3000: 1.121
# Starting epoch 29
# Loss after mini-batch   500: 1.134
# Loss after mini-batch  1000: 1.115
# Loss after mini-batch  1500: 1.136
# Loss after mini-batch  2000: 1.130
# Loss after mini-batch  2500: 1.128
# Loss after mini-batch  3000: 1.133
# Starting epoch 30
# Loss after mini-batch   500: 1.122
# Loss after mini-batch  1000: 1.122
# Loss after mini-batch  1500: 1.142
# Loss after mini-batch  2000: 1.129
# Loss after mini-batch  2500: 1.120
# Loss after mini-batch  3000: 1.131
# Starting epoch 31
# Loss after mini-batch   500: 1.127
# Loss after mini-batch  1000: 1.124
# Loss after mini-batch  1500: 1.138
# Loss after mini-batch  2000: 1.128
# Loss after mini-batch  2500: 1.115
# Loss after mini-batch  3000: 1.130
# Starting epoch 32
# Loss after mini-batch   500: 1.126
# Loss after mini-batch  1000: 1.129
# Loss after mini-batch  1500: 1.133
# Loss after mini-batch  2000: 1.126
# Loss after mini-batch  2500: 1.133
# Loss after mini-batch  3000: 1.116
# Starting epoch 33
# Loss after mini-batch   500: 1.126
# Loss after mini-batch  1000: 1.118
# Loss after mini-batch  1500: 1.137
# Loss after mini-batch  2000: 1.122
# Loss after mini-batch  2500: 1.126
# Loss after mini-batch  3000: 1.130
# Starting epoch 34
# Loss after mini-batch   500: 1.112
# Loss after mini-batch  1000: 1.124
# Loss after mini-batch  1500: 1.116
# Loss after mini-batch  2000: 1.141
# Loss after mini-batch  2500: 1.128
# Loss after mini-batch  3000: 1.127
# Starting epoch 35
# Loss after mini-batch   500: 1.111
# Loss after mini-batch  1000: 1.130
# Loss after mini-batch  1500: 1.116
# Loss after mini-batch  2000: 1.118
# Loss after mini-batch  2500: 1.147
# Loss after mini-batch  3000: 1.122
# Starting epoch 36
# Loss after mini-batch   500: 1.135
# Loss after mini-batch  1000: 1.116
# Loss after mini-batch  1500: 1.123
# Loss after mini-batch  2000: 1.120
# Loss after mini-batch  2500: 1.133
# Loss after mini-batch  3000: 1.119
# ERROR: Unexpected segmentation fault encountered in worker.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[233], line 77
#      74 # Set current loss value
#      75 current_loss = 0.0
# ---> 77 for i, data in enumerate(trainloader, 0):
#      78
#      79       # Get inputs
#      80       inputs, targets = data
#      82       # Prepare targets
#      83       #targets = targets.type(torch.FloatTensor).reshape((targets.shape[0], 4))
#      84
#      85       # Zero the gradients
#
# File ~/opt/anaconda3/envs/py4sci/lib/python3.10/site-packages/torch/utils/data/dataloader.py:634, in _BaseDataLoaderIter.__next__(self)
#     631 if self._sampler_iter is None:
#     632     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633     self._reset()  # type: ignore[call-arg]
# --> 634 data = self._next_data()
#     635 self._num_yielded += 1
#     636 if self._dataset_kind == _DatasetKind.Iterable and \
#     637         self._IterableDataset_len_called is not None and \
#     638         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/opt/anaconda3/envs/py4sci/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1318, in _MultiProcessingDataLoaderIter._next_data(self)
#    1315 else:
#    1316     # no valid `self._rcvd_idx` is found (i.e., didn't break)
#    1317     if not self._persistent_workers:
# -> 1318         self._shutdown_workers()
#    1319     raise StopIteration
#    1321 # Now `self._rcvd_idx` is the batch index we want to fetch
#    1322
#    1323 # Check if the next sample has already been generated
#
# File ~/opt/anaconda3/envs/py4sci/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1443, in _MultiProcessingDataLoaderIter._shutdown_workers(self)
#    1438         self._mark_worker_as_unavailable(worker_id, shutdown=True)
#    1439 for w in self._workers:
#    1440     # We should be able to join here, but in case anything went
#    1441     # wrong, we set a timeout and if the workers fail to join,
#    1442     # they are killed in the `finally` block.
# -> 1443     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#    1444 for q in self._index_queues:
#    1445     q.cancel_join_thread()
#
# File ~/opt/anaconda3/envs/py4sci/lib/python3.10/multiprocessing/process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File ~/opt/anaconda3/envs/py4sci/lib/python3.10/multiprocessing/popen_fork.py:40, in Popen.wait(self, timeout)
#      38 if timeout is not None:
#      39     from multiprocessing.connection import wait
# ---> 40     if not wait([self.sentinel], timeout):
#      41         return None
#      42 # This shouldn't block if wait() returned successfully.
#
# File ~/opt/anaconda3/envs/py4sci/lib/python3.10/multiprocessing/connection.py:931, in wait(object_list, timeout)
#     928     deadline = time.monotonic() + timeout
#     930 while True:
# --> 931     ready = selector.select(timeout)
#     932     if ready:
#     933         return [key.fileobj for (key, events) in ready]
#
# File ~/opt/anaconda3/envs/py4sci/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# File ~/opt/anaconda3/envs/py4sci/lib/python3.10/site-packages/torch/utils/data/_utils/signal_handling.py:66, in _set_SIGCHLD_handler.<locals>.handler(signum, frame)
#      63 def handler(signum, frame):
#      64     # This following call uses `waitid` with WNOHANG from C side. Therefore,
#      65     # Python can still get and update the process status successfully.
# ---> 66     _error_if_any_worker_fails()
#      67     if previous_handler is not None:
#      68         assert callable(previous_handler)
#
# RuntimeError: DataLoader worker (pid 36683) is killed by signal: Segmentation fault: 11.

# %%
torch.save(mlp.state_dict(), 'KMeans/model.pth')

# %%
reports = []

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

i=40

scale = StandardScaler()
X_train_normalized = scale.fit_transform(tf_x_train.toarray())
X_valid_normalized = scale.fit_transform(tf_x_valid.toarray())

kmeans = MiniBatchKMeans(n_clusters=i, random_state=10, n_init=10)
nn_X_train = kmeans.fit_transform(tf_x_train.toarray().astype(float))
preds = kmeans.fit_transform(tf_x_valid.toarray().astype(float))
nn_X_train_normalized = scale.fit_transform(nn_X_train)
nn_X_valid_normalized = scale.fit_transform(preds)
print(nn_X_valid_normalized.shape)
print(nn_X_train_normalized.shape)
#from sklearn.preprocessing import OneHotEncoder
#encoder = OneHotEncoder(sparse=False)
#nn_Y_train = encoder.fit_transform(Y_train.array.reshape(-1,1))
#nn_Y_valid = encoder.fit_transform(Y_valid.array.reshape(-1,1))
#nn_Y_valid
import torch
import torch.nn as nn
class MLP(nn.Module):
  '''
    Multilayer Perceptron.
  '''
  def __init__(self):
    super().__init__()
    self.layers = nn.Sequential(
      nn.Flatten(),
      nn.Linear(i, 64),
      nn.ReLU(),
      nn.Linear(64, 128),
      nn.ReLU(),
      nn.Linear(128, 256),
      nn.ReLU(),
      nn.Linear(256,64),
      nn.ReLU(),
      nn.Linear(64,5),
      nn.LogSoftmax(dim=1)
    )


  def forward(self, x):
    '''Forward pass'''
    return self.layers(x)

import torch
import torch.nn as nn
# Define the number of input features



Y_tensor = torch.tensor(Y_train.array).long()
X_tensor = torch.tensor(nn_X_train_normalized).float()
mlp = MLP()
#print(X_tensor.shape)
# make a dataset object
dataset = torch.utils.data.TensorDataset(X_tensor, Y_tensor)

# then use it to make a dataloader object
trainloader = torch.utils.data.DataLoader(dataset, batch_size=10, shuffle=True, num_workers=4)
# make a scoring function
loss_function = nn.NLLLoss()
optimizer = torch.optim.Adam(mlp.parameters(), lr=0.001)

num_epochs = 100

for epoch in range(0, num_epochs): # num_epochs at maximum

      # Print epoch
      print(f'Starting epoch {epoch+1}')

      # Set current loss value
      current_loss = 0.0
      
      for i, data in enumerate(trainloader, 0):

            # Get inputs
            inputs, targets = data
            
            # Prepare targets
            #targets = targets.type(torch.FloatTensor).reshape((targets.shape[0], 4))

            # Zero the gradients
            optimizer.zero_grad()

            # Perform forward pass
            outputs = mlp(inputs)
            #print(outputs.shape)
            #print(targets[4].value)
            # Compute loss
            loss = loss_function(outputs, targets)

            # Perform backward pass
            loss.backward()

            # Perform optimization
            optimizer.step()

            # Print statistics

            current_loss += loss.item()
            if i % 500 == 499:
                  print('Loss after mini-batch %5d: %.3f' %
                        (i + 1, current_loss / 500))
                  current_loss = 0.0



#plt.scatter(trainX[:,0], trainX[:, 1], c=pred_labels)



X_valid_tensor = torch.tensor(nn_X_valid_normalized).float()
preds = mlp(X_tensor).detach().numpy()

preds
test_output_labels = np.argmax(preds,1)

report=classification_report(Y_train.array, test_output_labels.astype(int),output_dict=True)
reports.append((report, i))
print(report)
# Out:
# (30591, 40)
# (30591, 40)
# Starting epoch 1
# Loss after mini-batch   500: 1.233
# Loss after mini-batch  1000: 1.194
# Loss after mini-batch  1500: 1.193
# Loss after mini-batch  2000: 1.184
# Loss after mini-batch  2500: 1.189
# Loss after mini-batch  3000: 1.179
# Starting epoch 2
# Loss after mini-batch   500: 1.176
# Loss after mini-batch  1000: 1.174
# Loss after mini-batch  1500: 1.178
# Loss after mini-batch  2000: 1.202
# Loss after mini-batch  2500: 1.180
# Loss after mini-batch  3000: 1.184
# Starting epoch 3
# Loss after mini-batch   500: 1.173
# Loss after mini-batch  1000: 1.184
# Loss after mini-batch  1500: 1.168
# Loss after mini-batch  2000: 1.179
# Loss after mini-batch  2500: 1.182
# Loss after mini-batch  3000: 1.177
# Starting epoch 4
# Loss after mini-batch   500: 1.175
# Loss after mini-batch  1000: 1.183
# Loss after mini-batch  1500: 1.167
# Loss after mini-batch  2000: 1.173
# Loss after mini-batch  2500: 1.181
# Loss after mini-batch  3000: 1.169
# Starting epoch 5
# Loss after mini-batch   500: 1.166
# Loss after mini-batch  1000: 1.173
# Loss after mini-batch  1500: 1.160
# Loss after mini-batch  2000: 1.171
# Loss after mini-batch  2500: 1.183
# Loss after mini-batch  3000: 1.173
# Starting epoch 6
# Loss after mini-batch   500: 1.176
# Loss after mini-batch  1000: 1.173
# Loss after mini-batch  1500: 1.163
# Loss after mini-batch  2000: 1.170
# Loss after mini-batch  2500: 1.165
# Loss after mini-batch  3000: 1.166
# Starting epoch 7
# Loss after mini-batch   500: 1.165
# Loss after mini-batch  1000: 1.159
# Loss after mini-batch  1500: 1.164
# Loss after mini-batch  2000: 1.163
# Loss after mini-batch  2500: 1.172
# Loss after mini-batch  3000: 1.176
# Starting epoch 8
# Loss after mini-batch   500: 1.150
# Loss after mini-batch  1000: 1.170
# Loss after mini-batch  1500: 1.160
# Loss after mini-batch  2000: 1.171
# Loss after mini-batch  2500: 1.161
# Loss after mini-batch  3000: 1.166
# Starting epoch 9
# Loss after mini-batch   500: 1.158
# Loss after mini-batch  1000: 1.159
# Loss after mini-batch  1500: 1.163
# Loss after mini-batch  2000: 1.159
# Loss after mini-batch  2500: 1.164
# Loss after mini-batch  3000: 1.166
# Starting epoch 10
# Loss after mini-batch   500: 1.160
# Loss after mini-batch  1000: 1.157
# Loss after mini-batch  1500: 1.169
# Loss after mini-batch  2000: 1.165
# Loss after mini-batch  2500: 1.161
# Loss after mini-batch  3000: 1.153
# Starting epoch 11
# Loss after mini-batch   500: 1.169
# Loss after mini-batch  1000: 1.146
# Loss after mini-batch  1500: 1.169
# Loss after mini-batch  2000: 1.167
# Loss after mini-batch  2500: 1.154
# Loss after mini-batch  3000: 1.159
# Starting epoch 12
# Loss after mini-batch   500: 1.163
# Loss after mini-batch  1000: 1.164
# Loss after mini-batch  1500: 1.160
# Loss after mini-batch  2000: 1.159
# Loss after mini-batch  2500: 1.146
# Loss after mini-batch  3000: 1.151
# Starting epoch 13
# Loss after mini-batch   500: 1.153
# Loss after mini-batch  1000: 1.155
# Loss after mini-batch  1500: 1.157
# Loss after mini-batch  2000: 1.157
# Loss after mini-batch  2500: 1.165
# Loss after mini-batch  3000: 1.150
# Starting epoch 14
# Loss after mini-batch   500: 1.142
# Loss after mini-batch  1000: 1.166
# Loss after mini-batch  1500: 1.168
# Loss after mini-batch  2000: 1.157
# Loss after mini-batch  2500: 1.162
# Loss after mini-batch  3000: 1.145
# Starting epoch 15
# Loss after mini-batch   500: 1.146
# Loss after mini-batch  1000: 1.161
# Loss after mini-batch  1500: 1.152
# Loss after mini-batch  2000: 1.149
# Loss after mini-batch  2500: 1.153
# Loss after mini-batch  3000: 1.155
# Starting epoch 16
# Loss after mini-batch   500: 1.151
# Loss after mini-batch  1000: 1.149
# Loss after mini-batch  1500: 1.155
# Loss after mini-batch  2000: 1.140
# Loss after mini-batch  2500: 1.157
# Loss after mini-batch  3000: 1.160
# Starting epoch 17
# Loss after mini-batch   500: 1.156
# Loss after mini-batch  1000: 1.151
# Loss after mini-batch  1500: 1.155
# Loss after mini-batch  2000: 1.138
# Loss after mini-batch  2500: 1.150
# Loss after mini-batch  3000: 1.151
# Starting epoch 18
# Loss after mini-batch   500: 1.134
# Loss after mini-batch  1000: 1.165
# Loss after mini-batch  1500: 1.151
# Loss after mini-batch  2000: 1.150
# Loss after mini-batch  2500: 1.148
# Loss after mini-batch  3000: 1.155
# Starting epoch 19
# Loss after mini-batch   500: 1.145
# Loss after mini-batch  1000: 1.153
# Loss after mini-batch  1500: 1.152
# Loss after mini-batch  2000: 1.141
# Loss after mini-batch  2500: 1.150
# Loss after mini-batch  3000: 1.153
# Starting epoch 20
# Loss after mini-batch   500: 1.146
# Loss after mini-batch  1000: 1.126
# Loss after mini-batch  1500: 1.155
# Loss after mini-batch  2000: 1.158
# Loss after mini-batch  2500: 1.144
# Loss after mini-batch  3000: 1.159
# Starting epoch 21
# Loss after mini-batch   500: 1.143
# Loss after mini-batch  1000: 1.138
# Loss after mini-batch  1500: 1.137
# Loss after mini-batch  2000: 1.152
# Loss after mini-batch  2500: 1.151
# Loss after mini-batch  3000: 1.155
# Starting epoch 22
# Loss after mini-batch   500: 1.140
# Loss after mini-batch  1000: 1.139
# Loss after mini-batch  1500: 1.139
# Loss after mini-batch  2000: 1.144
# Loss after mini-batch  2500: 1.158
# Loss after mini-batch  3000: 1.154
# Starting epoch 23
# Loss after mini-batch   500: 1.136
# Loss after mini-batch  1000: 1.140
# Loss after mini-batch  1500: 1.151
# Loss after mini-batch  2000: 1.146
# Loss after mini-batch  2500: 1.150
# Loss after mini-batch  3000: 1.144
# Starting epoch 24
# Loss after mini-batch   500: 1.128
# Loss after mini-batch  1000: 1.144
# Loss after mini-batch  1500: 1.146
# Loss after mini-batch  2000: 1.146
# Loss after mini-batch  2500: 1.148
# Loss after mini-batch  3000: 1.140
# Starting epoch 25
# Loss after mini-batch   500: 1.149
# Loss after mini-batch  1000: 1.136
# Loss after mini-batch  1500: 1.136
# Loss after mini-batch  2000: 1.128
# Loss after mini-batch  2500: 1.159
# Loss after mini-batch  3000: 1.149
# Starting epoch 26
# Loss after mini-batch   500: 1.136
# Loss after mini-batch  1000: 1.148
# Loss after mini-batch  1500: 1.145
# Loss after mini-batch  2000: 1.144
# Loss after mini-batch  2500: 1.135
# Loss after mini-batch  3000: 1.140
# Starting epoch 27
# Loss after mini-batch   500: 1.132
# Loss after mini-batch  1000: 1.136
# Loss after mini-batch  1500: 1.157
# Loss after mini-batch  2000: 1.131
# Loss after mini-batch  2500: 1.137
# Loss after mini-batch  3000: 1.147
# Starting epoch 28
# Loss after mini-batch   500: 1.129
# Loss after mini-batch  1000: 1.136
# Loss after mini-batch  1500: 1.140
# Loss after mini-batch  2000: 1.137
# Loss after mini-batch  2500: 1.156
# Loss after mini-batch  3000: 1.142
# Starting epoch 29
# Loss after mini-batch   500: 1.121
# Loss after mini-batch  1000: 1.135
# Loss after mini-batch  1500: 1.142
# Loss after mini-batch  2000: 1.139
# Loss after mini-batch  2500: 1.135
# Loss after mini-batch  3000: 1.155
# Starting epoch 30
# Loss after mini-batch   500: 1.132
# Loss after mini-batch  1000: 1.143
# Loss after mini-batch  1500: 1.111
# Loss after mini-batch  2000: 1.131
# Loss after mini-batch  2500: 1.144
# Loss after mini-batch  3000: 1.175
# Starting epoch 31
# Loss after mini-batch   500: 1.129
# Loss after mini-batch  1000: 1.140
# Loss after mini-batch  1500: 1.139
# Loss after mini-batch  2000: 1.132
# Loss after mini-batch  2500: 1.134
# Loss after mini-batch  3000: 1.143
# Starting epoch 32
# Loss after mini-batch   500: 1.124
# Loss after mini-batch  1000: 1.118
# Loss after mini-batch  1500: 1.134
# Loss after mini-batch  2000: 1.141
# Loss after mini-batch  2500: 1.148
# Loss after mini-batch  3000: 1.141
# Starting epoch 33
# Loss after mini-batch   500: 1.147
# Loss after mini-batch  1000: 1.128
# Loss after mini-batch  1500: 1.126
# Loss after mini-batch  2000: 1.128
# Loss after mini-batch  2500: 1.133
# Loss after mini-batch  3000: 1.146
# Starting epoch 34
# Loss after mini-batch   500: 1.131
# Loss after mini-batch  1000: 1.134
# Loss after mini-batch  1500: 1.134
# Loss after mini-batch  2000: 1.144
# Loss after mini-batch  2500: 1.138
# Loss after mini-batch  3000: 1.126
# Starting epoch 35
# Loss after mini-batch   500: 1.119
# Loss after mini-batch  1000: 1.142
# Loss after mini-batch  1500: 1.120
# Loss after mini-batch  2000: 1.145
# Loss after mini-batch  2500: 1.145
# Loss after mini-batch  3000: 1.134
# Starting epoch 36
# Loss after mini-batch   500: 1.132
# Loss after mini-batch  1000: 1.126
# Loss after mini-batch  1500: 1.132
# Loss after mini-batch  2000: 1.139
# Loss after mini-batch  2500: 1.136
# Loss after mini-batch  3000: 1.132
# Starting epoch 37
# Loss after mini-batch   500: 1.118
# Loss after mini-batch  1000: 1.141
# Loss after mini-batch  1500: 1.142
# Loss after mini-batch  2000: 1.118
# Loss after mini-batch  2500: 1.140
# Loss after mini-batch  3000: 1.144
# Starting epoch 38
# Loss after mini-batch   500: 1.129
# Loss after mini-batch  1000: 1.143
# Loss after mini-batch  1500: 1.123
# Loss after mini-batch  2000: 1.127
# Loss after mini-batch  2500: 1.138
# Loss after mini-batch  3000: 1.131
# Starting epoch 39
# Loss after mini-batch   500: 1.124
# Loss after mini-batch  1000: 1.138
# Loss after mini-batch  1500: 1.138
# Loss after mini-batch  2000: 1.137
# Loss after mini-batch  2500: 1.121
# Loss after mini-batch  3000: 1.129
# Starting epoch 40
# Loss after mini-batch   500: 1.129
# Loss after mini-batch  1000: 1.128
# Loss after mini-batch  1500: 1.126
# Loss after mini-batch  2000: 1.143
# Loss after mini-batch  2500: 1.123
# Loss after mini-batch  3000: 1.122
# Starting epoch 41
# Loss after mini-batch   500: 1.123
# Loss after mini-batch  1000: 1.133
# Loss after mini-batch  1500: 1.131
# Loss after mini-batch  2000: 1.137
# Loss after mini-batch  2500: 1.125
# Loss after mini-batch  3000: 1.124
# Starting epoch 42
# Loss after mini-batch   500: 1.116
# Loss after mini-batch  1000: 1.133
# Loss after mini-batch  1500: 1.135
# Loss after mini-batch  2000: 1.121
# Loss after mini-batch  2500: 1.132
# Loss after mini-batch  3000: 1.139
# Starting epoch 43
# Loss after mini-batch   500: 1.117
# Loss after mini-batch  1000: 1.130
# Loss after mini-batch  1500: 1.134
# Loss after mini-batch  2000: 1.123
# Loss after mini-batch  2500: 1.138
# Loss after mini-batch  3000: 1.115
# Starting epoch 44
# Loss after mini-batch   500: 1.132
# Loss after mini-batch  1000: 1.128
# Loss after mini-batch  1500: 1.132
# Loss after mini-batch  2000: 1.129
# Loss after mini-batch  2500: 1.131
# Loss after mini-batch  3000: 1.115
# Starting epoch 45
# Loss after mini-batch   500: 1.123
# Loss after mini-batch  1000: 1.143
# Loss after mini-batch  1500: 1.136
# Loss after mini-batch  2000: 1.104
# Loss after mini-batch  2500: 1.119
# Loss after mini-batch  3000: 1.132
# Starting epoch 46
# Loss after mini-batch   500: 1.124
# Loss after mini-batch  1000: 1.129
# Loss after mini-batch  1500: 1.123
# Loss after mini-batch  2000: 1.134
# Loss after mini-batch  2500: 1.122
# Loss after mini-batch  3000: 1.126
# Starting epoch 47
# Loss after mini-batch   500: 1.125
# Loss after mini-batch  1000: 1.124
# Loss after mini-batch  1500: 1.118
# Loss after mini-batch  2000: 1.125
# Loss after mini-batch  2500: 1.122
# Loss after mini-batch  3000: 1.133
# Starting epoch 48
# Loss after mini-batch   500: 1.130
# Loss after mini-batch  1000: 1.128
# Loss after mini-batch  1500: 1.131
# Loss after mini-batch  2000: 1.123
# Loss after mini-batch  2500: 1.127
# Loss after mini-batch  3000: 1.118
# Starting epoch 49
# Loss after mini-batch   500: 1.122
# Loss after mini-batch  1000: 1.128
# Loss after mini-batch  1500: 1.112
# Loss after mini-batch  2000: 1.122
# Loss after mini-batch  2500: 1.135
# Loss after mini-batch  3000: 1.132
# Starting epoch 50
# Loss after mini-batch   500: 1.120
# Loss after mini-batch  1000: 1.118
# Loss after mini-batch  1500: 1.125
# Loss after mini-batch  2000: 1.128
# Loss after mini-batch  2500: 1.128
# Loss after mini-batch  3000: 1.120
# Starting epoch 51
# Loss after mini-batch   500: 1.119
# Loss after mini-batch  1000: 1.122
# Loss after mini-batch  1500: 1.136
# Loss after mini-batch  2000: 1.116
# Loss after mini-batch  2500: 1.128
# Loss after mini-batch  3000: 1.118
# Starting epoch 52
# Loss after mini-batch   500: 1.122
# Loss after mini-batch  1000: 1.124
# Loss after mini-batch  1500: 1.122
# Loss after mini-batch  2000: 1.121
# Loss after mini-batch  2500: 1.125
# Loss after mini-batch  3000: 1.136
# Starting epoch 53
# Loss after mini-batch   500: 1.124
# Loss after mini-batch  1000: 1.101
# Loss after mini-batch  1500: 1.114
# Loss after mini-batch  2000: 1.126
# Loss after mini-batch  2500: 1.129
# Loss after mini-batch  3000: 1.144
# Starting epoch 54
# Loss after mini-batch   500: 1.114
# Loss after mini-batch  1000: 1.121
# Loss after mini-batch  1500: 1.115
# Loss after mini-batch  2000: 1.136
# Loss after mini-batch  2500: 1.137
# Loss after mini-batch  3000: 1.118
# Starting epoch 55
# Loss after mini-batch   500: 1.129
# Loss after mini-batch  1000: 1.118
# Loss after mini-batch  1500: 1.113
# Loss after mini-batch  2000: 1.119
# Loss after mini-batch  2500: 1.119
# Loss after mini-batch  3000: 1.128
# Starting epoch 56
# Loss after mini-batch   500: 1.109
# Loss after mini-batch  1000: 1.116
# Loss after mini-batch  1500: 1.122
# Loss after mini-batch  2000: 1.135
# Loss after mini-batch  2500: 1.121
# Loss after mini-batch  3000: 1.127
# Starting epoch 57
# Loss after mini-batch   500: 1.105
# Loss after mini-batch  1000: 1.130
# Loss after mini-batch  1500: 1.131
# Loss after mini-batch  2000: 1.127
# Loss after mini-batch  2500: 1.119
# Loss after mini-batch  3000: 1.112
# Starting epoch 58
# Loss after mini-batch   500: 1.129
# Loss after mini-batch  1000: 1.132
# Loss after mini-batch  1500: 1.109
# Loss after mini-batch  2000: 1.116
# Loss after mini-batch  2500: 1.129
# Loss after mini-batch  3000: 1.108
# Starting epoch 59
# Loss after mini-batch   500: 1.101
# Loss after mini-batch  1000: 1.104
# Loss after mini-batch  1500: 1.122
# Loss after mini-batch  2000: 1.131
# Loss after mini-batch  2500: 1.133
# Loss after mini-batch  3000: 1.128
# Starting epoch 60
# Loss after mini-batch   500: 1.113
# Loss after mini-batch  1000: 1.133
# Loss after mini-batch  1500: 1.124
# Loss after mini-batch  2000: 1.121
# Loss after mini-batch  2500: 1.118
# Loss after mini-batch  3000: 1.118
# Starting epoch 61
# Loss after mini-batch   500: 1.119
# Loss after mini-batch  1000: 1.124
# Loss after mini-batch  1500: 1.117
# Loss after mini-batch  2000: 1.125
# Loss after mini-batch  2500: 1.124
# Loss after mini-batch  3000: 1.121
# Starting epoch 62
# Loss after mini-batch   500: 1.124
# Loss after mini-batch  1000: 1.127
# Loss after mini-batch  1500: 1.113
# Loss after mini-batch  2000: 1.137
# Loss after mini-batch  2500: 1.124
# Loss after mini-batch  3000: 1.103
# Starting epoch 63
# Loss after mini-batch   500: 1.136
# Loss after mini-batch  1000: 1.129
# Loss after mini-batch  1500: 1.121
# Loss after mini-batch  2000: 1.119
# Loss after mini-batch  2500: 1.120
# Loss after mini-batch  3000: 1.087
# Starting epoch 64
# Loss after mini-batch   500: 1.114
# Loss after mini-batch  1000: 1.120
# Loss after mini-batch  1500: 1.120
# Loss after mini-batch  2000: 1.112
# Loss after mini-batch  2500: 1.130
# Loss after mini-batch  3000: 1.119
# Starting epoch 65
# Loss after mini-batch   500: 1.114
# Loss after mini-batch  1000: 1.122
# Loss after mini-batch  1500: 1.119
# Loss after mini-batch  2000: 1.123
# Loss after mini-batch  2500: 1.113
# Loss after mini-batch  3000: 1.120
# Starting epoch 66
# Loss after mini-batch   500: 1.104
# Loss after mini-batch  1000: 1.116
# Loss after mini-batch  1500: 1.127
# Loss after mini-batch  2000: 1.108
# Loss after mini-batch  2500: 1.138
# Loss after mini-batch  3000: 1.122
# Starting epoch 67
# Loss after mini-batch   500: 1.115
# Loss after mini-batch  1000: 1.134
# Loss after mini-batch  1500: 1.111
# Loss after mini-batch  2000: 1.113
# Loss after mini-batch  2500: 1.123
# Loss after mini-batch  3000: 1.130
# Starting epoch 68
# Loss after mini-batch   500: 1.110
# Loss after mini-batch  1000: 1.113
# Loss after mini-batch  1500: 1.131
# Loss after mini-batch  2000: 1.102
# Loss after mini-batch  2500: 1.139
# Loss after mini-batch  3000: 1.116
# Starting epoch 69
# Loss after mini-batch   500: 1.113
# Loss after mini-batch  1000: 1.124
# Loss after mini-batch  1500: 1.115
# Loss after mini-batch  2000: 1.121
# Loss after mini-batch  2500: 1.114
# Loss after mini-batch  3000: 1.127
# Starting epoch 70
# Loss after mini-batch   500: 1.233
# Loss after mini-batch  1000: 1.123
# Loss after mini-batch  1500: 1.121
# Loss after mini-batch  2000: 1.110
# Loss after mini-batch  2500: 1.105
# Loss after mini-batch  3000: 1.122
# Starting epoch 71
# Loss after mini-batch   500: 1.124
# Loss after mini-batch  1000: 1.112
# Loss after mini-batch  1500: 1.112
# Loss after mini-batch  2000: 1.113
# Loss after mini-batch  2500: 1.116
# Loss after mini-batch  3000: 1.124
# Starting epoch 72
# Loss after mini-batch   500: 1.103
# Loss after mini-batch  1000: 1.108
# Loss after mini-batch  1500: 1.128
# Loss after mini-batch  2000: 1.121
# Loss after mini-batch  2500: 1.132
# Loss after mini-batch  3000: 1.114
# Starting epoch 73
# Loss after mini-batch   500: 1.110
# Loss after mini-batch  1000: 1.109
# Loss after mini-batch  1500: 1.123
# Loss after mini-batch  2000: 1.119
# Loss after mini-batch  2500: 1.120
# Loss after mini-batch  3000: 1.112
# Starting epoch 74
# Loss after mini-batch   500: 1.114
# Loss after mini-batch  1000: 1.110
# Loss after mini-batch  1500: 1.109
# Loss after mini-batch  2000: 1.130
# Loss after mini-batch  2500: 1.113
# Loss after mini-batch  3000: 1.148
# Starting epoch 75
# Loss after mini-batch   500: 1.133
# Loss after mini-batch  1000: 1.104
# Loss after mini-batch  1500: 1.110
# Loss after mini-batch  2000: 1.113
# Loss after mini-batch  2500: 1.127
# Loss after mini-batch  3000: 1.132
# Starting epoch 76
# Loss after mini-batch   500: 1.119
# Loss after mini-batch  1000: 1.125
# Loss after mini-batch  1500: 1.112
# Loss after mini-batch  2000: 1.113
# Loss after mini-batch  2500: 1.115
# Loss after mini-batch  3000: 1.110
# Starting epoch 77
# Loss after mini-batch   500: 1.117
# Loss after mini-batch  1000: 1.119
# Loss after mini-batch  1500: 1.102
# Loss after mini-batch  2000: 1.106
# Loss after mini-batch  2500: 1.125
# Loss after mini-batch  3000: 1.116
# Starting epoch 78
# Loss after mini-batch   500: 1.108
# Loss after mini-batch  1000: 1.123
# Loss after mini-batch  1500: 1.111
# Loss after mini-batch  2000: 1.122
# Loss after mini-batch  2500: 1.124
# Loss after mini-batch  3000: 1.113
# Starting epoch 79
# Loss after mini-batch   500: 1.109
# Loss after mini-batch  1000: 1.106
# Loss after mini-batch  1500: 2.305
# Loss after mini-batch  2000: 1.117
# Loss after mini-batch  2500: 1.106
# Loss after mini-batch  3000: 1.116
# Starting epoch 80
# Loss after mini-batch   500: 1.094
# Loss after mini-batch  1000: 1.130
# Loss after mini-batch  1500: 1.105
# Loss after mini-batch  2000: 1.114
# Loss after mini-batch  2500: 1.105
# Loss after mini-batch  3000: 1.121
# Starting epoch 81
# Loss after mini-batch   500: 1.126
# Loss after mini-batch  1000: 1.117
# Loss after mini-batch  1500: 1.104
# Loss after mini-batch  2000: 1.110
# Loss after mini-batch  2500: 1.113
# Loss after mini-batch  3000: 1.104
# Starting epoch 82
# Loss after mini-batch   500: 1.115
# Loss after mini-batch  1000: 1.125
# Loss after mini-batch  1500: 1.116
# Loss after mini-batch  2000: 1.100
# Loss after mini-batch  2500: 1.112
# Loss after mini-batch  3000: 1.113
# Starting epoch 83
# Loss after mini-batch   500: 1.098
# Loss after mini-batch  1000: 1.124
# Loss after mini-batch  1500: 1.118
# Loss after mini-batch  2000: 1.113
# Loss after mini-batch  2500: 1.117
# Loss after mini-batch  3000: 1.120
# Starting epoch 84
# Loss after mini-batch   500: 1.123
# Loss after mini-batch  1000: 1.124
# Loss after mini-batch  1500: 1.114
# Loss after mini-batch  2000: 1.115
# Loss after mini-batch  2500: 1.112
# Loss after mini-batch  3000: 1.104
# Starting epoch 85
# Loss after mini-batch   500: 1.116
# Loss after mini-batch  1000: 1.117
# Loss after mini-batch  1500: 1.113
# Loss after mini-batch  2000: 1.106
# Loss after mini-batch  2500: 1.128
# Loss after mini-batch  3000: 1.113
# Starting epoch 86
# Loss after mini-batch   500: 1.093
# Loss after mini-batch  1000: 1.105
# Loss after mini-batch  1500: 1.114
# Loss after mini-batch  2000: 1.112
# Loss after mini-batch  2500: 1.130
# Loss after mini-batch  3000: 1.121
# Starting epoch 87
# Loss after mini-batch   500: 1.114
# Loss after mini-batch  1000: 1.117
# Loss after mini-batch  1500: 1.110
# Loss after mini-batch  2000: 1.109
# Loss after mini-batch  2500: 1.113
# Loss after mini-batch  3000: 1.118
# Starting epoch 88
# Loss after mini-batch   500: 1.107
# Loss after mini-batch  1000: 1.101
# Loss after mini-batch  1500: 1.108
# Loss after mini-batch  2000: 1.121
# Loss after mini-batch  2500: 1.108
# Loss after mini-batch  3000: 1.116
# Starting epoch 89
# Loss after mini-batch   500: 1.119
# Loss after mini-batch  1000: 1.117
# Loss after mini-batch  1500: 1.106
# Loss after mini-batch  2000: 1.098
# Loss after mini-batch  2500: 1.115
# Loss after mini-batch  3000: 1.114
# Starting epoch 90
# Loss after mini-batch   500: 1.106
# Loss after mini-batch  1000: 1.137
# Loss after mini-batch  1500: 1.119
# Loss after mini-batch  2000: 1.111
# Loss after mini-batch  2500: 1.116
# Loss after mini-batch  3000: 1.105
# Starting epoch 91
# Loss after mini-batch   500: 1.110
# Loss after mini-batch  1000: 1.114
# Loss after mini-batch  1500: 1.122
# Loss after mini-batch  2000: 1.104
# Loss after mini-batch  2500: 1.120
# Loss after mini-batch  3000: 1.113
# Starting epoch 92
# Loss after mini-batch   500: 1.108
# Loss after mini-batch  1000: 1.119
# Loss after mini-batch  1500: 1.109
# Loss after mini-batch  2000: 1.111
# Loss after mini-batch  2500: 1.108
# Loss after mini-batch  3000: 1.117
# Starting epoch 93
# Loss after mini-batch   500: 1.107
# Loss after mini-batch  1000: 1.122
# Loss after mini-batch  1500: 1.107
# Loss after mini-batch  2000: 1.108
# Loss after mini-batch  2500: 1.105
# Loss after mini-batch  3000: 1.125
# Starting epoch 94
# Loss after mini-batch   500: 1.099
# Loss after mini-batch  1000: 1.107
# Loss after mini-batch  1500: 1.104
# Loss after mini-batch  2000: 1.109
# Loss after mini-batch  2500: 1.203
# Loss after mini-batch  3000: 1.136
# Starting epoch 95
# Loss after mini-batch   500: 1.100
# Loss after mini-batch  1000: 1.100
# Loss after mini-batch  1500: 1.120
# Loss after mini-batch  2000: 1.111
# Loss after mini-batch  2500: 1.119
# Loss after mini-batch  3000: 1.114
# Starting epoch 96
# Loss after mini-batch   500: 1.112
# Loss after mini-batch  1000: 1.107
# Loss after mini-batch  1500: 1.107
# Loss after mini-batch  2000: 1.103
# Loss after mini-batch  2500: 1.119
# Loss after mini-batch  3000: 1.112
# Starting epoch 97
# Loss after mini-batch   500: 1.102
# Loss after mini-batch  1000: 1.106
# Loss after mini-batch  1500: 1.125
# Loss after mini-batch  2000: 1.130
# Loss after mini-batch  2500: 1.099
# Loss after mini-batch  3000: 1.119
# Starting epoch 98
# Loss after mini-batch   500: 1.098
# Loss after mini-batch  1000: 1.119
# Loss after mini-batch  1500: 1.170
# Loss after mini-batch  2000: 1.115
# Loss after mini-batch  2500: 1.112
# Loss after mini-batch  3000: 1.112
# Starting epoch 99
# Loss after mini-batch   500: 1.105
# Loss after mini-batch  1000: 1.128
# Loss after mini-batch  1500: 1.113
# Loss after mini-batch  2000: 1.099
# Loss after mini-batch  2500: 1.117
# Loss after mini-batch  3000: 1.112
# Starting epoch 100
# Loss after mini-batch   500: 1.107
# Loss after mini-batch  1000: 1.108
# Loss after mini-batch  1500: 1.100
# Loss after mini-batch  2000: 1.113
# Loss after mini-batch  2500: 1.116
# Loss after mini-batch  3000: 1.123
# {'0': {'precision': 0.6739130434782609, 'recall': 0.05541651769753307, 'f1-score': 0.10241162867525604, 'support': 2797}, '1': {'precision': 0.48309006763972945, 'recall': 0.37441368527545293, 'f1-score': 0.4218652849740933, 'support': 10873}, '3': {'precision': 0.4697238290725882, 'recall': 0.7617066343898934, 'f1-score': 0.5810994084547685, 'support': 13219}, '4': {'precision': 0.6465863453815262, 'recall': 0.08698001080497028, 'f1-score': 0.15333333333333332, 'support': 3702}, 'accuracy': 0.4778202739367788, 'macro avg': {'precision': 0.5683283213930261, 'recall': 0.31962921204196243, 'f1-score': 0.31467741385936276, 'support': 30591}, 'weighted avg': {'precision': 0.5145472536095069, 'recall': 0.4778202739367788, 'f1-score': 0.42896863944596747, 'support': 30591}}
